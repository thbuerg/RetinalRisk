# %% [markdown]
# # Benchmarks

# %% [markdown]
# ## Initialize

# %%
#library(Rmisc)
library(dtplyr)
library(tidyverse)
library(glue)
library(arrow)
library(patchwork)
library(data.table)
library("jsonlite")
library(ggthemes)
# Out:
# Warning message:
# “package ‘tidyverse’ was built under R version 4.0.3”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.5”
# Warning message:
# “package ‘readr’ was built under R version 4.0.5”
# Warning message:
# “package ‘purrr’ was built under R version 4.0.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.5”
# Warning message:
# “package ‘stringr’ was built under R version 4.0.5”
# Warning message:
# “package ‘forcats’ was built under R version 4.0.3”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Warning message:
# “package ‘arrow’ was built under R version 4.0.3”
#
# Attaching package: ‘arrow’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Warning message:
# “package ‘jsonlite’ was built under R version 4.0.3”
#
# Attaching package: ‘jsonlite’
#
#
# The following object is masked from ‘package:purrr’:
#
#     flatten
#
#
# Warning message:
# “package ‘ggthemes’ was built under R version 4.0.3”

# %%
if (grepl("sc", Sys.info()[["nodename"]], fixed=TRUE)) {
    base_path = "/sc-projects/sc-proj-ukb-cvd"
} else {
    base_path = "/data/analysis/ag-reils/ag-reils-shared/cardioRS"}
print(base_path)

project_label="22_medical_records"
project_path = glue("{base_path}/results/projects/{project_label}")
figure_path = glue("{project_path}/figures")
output_path = glue("{project_path}/data")

experiment = 220413
experiment_path = glue("{output_path}/{experiment}")
# Out:
# [1] "/sc-projects/sc-proj-ukb-cvd"

# %%
base_size = 8
title_size = 10
facet_size = 9
geom_text_size=3
theme_set(theme_classic(base_size = base_size) + 
          theme(strip.background = element_blank(), plot.title=element_text(size=title_size, hjust=0), 
                strip.text.x = element_text(size = facet_size),axis.title=element_text(size=10), axis.text=element_text(size=8, color="black"),
                legend.position="bottom", axis.line = element_line(size = 0.2), axis.ticks=element_line(size=0.2), panel.grid.major.y=element_line()))

# %%
colors_dict = read_json("colors.json")
color_map <- c(
    "Identity(AgeSex)+MLP" = colors_dict$pastel$red$mid,
    "Identity(Records)+MLP" = colors_dict$pastel$red$mid,
    "GNN(Records)+MLP" = colors_dict$pastel$red$mid,
    "Identity(AgeSex+Records)+MLP" = colors_dict$pastel$red$mid,
    "GNN(AgeSex+Records)+MLP" = colors_dict$pastel$red$mid
)

# %%
endpoint_defs = arrow::read_feather(glue("{output_path}/phecode_defs_220306.feather")) %>% arrange(endpoint)

# %%
endpoint_map = endpoint_defs$phecode_string
names(endpoint_map) =  endpoint_defs$endpoint
endpoint_order = (endpoint_defs %>% arrange(as.numeric(phecode)))$endpoint

# %%
endpoint_selection_df = endpoint_defs %>% filter(phecode_category == "Mental")# %>% filter(!str_detect(phecode, "\\."))
endpoint_selection = endpoint_selection_df$endpoint

# %%
endpoint_defs = endpoint_defs %>% 
    mutate(name = phecode_string) %>% 
    mutate(name = 
           case_when( 
               endpoint == "phecode_092-2"~"Sepsis", 
               #endpoint == "phecode_105"~"Malign breast cancer", 
               endpoint == "phecode_123"~"Malignant plasma cell neoplasms", 
               endpoint == "phecode_164"~"Anemia", 
               endpoint == "phecode_200-1"~"Hypothyroidism", 
               endpoint == "phecode_232"~"Vitamin deficiencies", 
               endpoint == "phecode_284"~"Suicide attempt or self harm", 
               #endpoint == "phecode_287-5"~"Drug-induced psychosis", 
               #endpoint == "phecode_328"~"Dementia", 
               #endpoint == "phecode_404"~"Coronary heart disease", 
               endpoint == "phecode_424"~"Heart failure", 
               endpoint == "phecode_440-11"~"Deep vein thrombosis", 
               endpoint == "phecode_468"~"Pneumonia", 
               endpoint == "phecode_474"~"COPD", 
               endpoint == "phecode_518"~"Appendicitis", 
               endpoint == "phecode_542-1"~"Fibrosis and cirrhosis of liver", 
               endpoint == "phecode_583"~"Chronic kidney disease", 
               endpoint == "phecode_705-1"~"Rheumatoid arthritis", 
               endpoint == "phecode_908-1"~"(Pre)eclampsia", 
               #endpoint == "phecode_976"~"Complication of anesthesia",
               TRUE ~ name)
           )

endpoint_map = endpoint_defs$name
names(endpoint_map) =  endpoint_defs$endpoint
endpoint_order = (endpoint_defs %>% arrange(as.numeric(phecode)))$endpoint

# %% [markdown]
# ## Load data

# %% [markdown]
# # Load Benchmarks

# %%
name = "benchmark_cindex_agesexcoxph_220421"
benchmark_endpoints = arrow::read_feather(glue("{experiment_path}/{name}.feather")) %>% left_join(endpoint_defs)
# Out:
# Joining, by = "endpoint"

# %%
benchmark_endpoints %>% group_by(endpoint, score)  %>% summarise(cindex=mean(cindex)) %>% group_by(score) %>% summarise(mean(cindex)) %>% arrange(`mean(cindex)`)
# Out:
# `summarise()` has grouped output by 'endpoint'. You can override using the `.groups` argument.
#   score                            mean(cindex)
# 1 Age+Sex                          0.6018211
# 2 Age+Sex+MedicalHistory+I(Age*MH) 0.7452907
# 3 MedicalHistory                   0.7456530
# 4 Age+Sex+MedicalHistory           0.7462709

# %%
endpoints_sorted = (benchmark_endpoints %>% 
    filter(score == "Age+Sex+MedicalHistory") %>% 
    group_by(endpoint, score) %>% 
    summarise(cindex=mean(cindex, na.rm=TRUE)) %>% 
    arrange(cindex) %>% ungroup())$endpoint
# Out:
# `summarise()` has grouped output by 'endpoint'. You can override using the `.groups` argument.

# %%
categories_sorted = (endpoint_defs %>% distinct(phecode_category))$phecode_category

# %%
plot_width = 10; plot_height=2.5; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

scores_plot = c("Age+Sex", "Age+Sex+MedicalHistory")#, "AgeSexMedicalHistory")

temp = benchmark_endpoints %>% 
    filter(score %in% scores_plot) %>% 
    mutate(score = factor(score, levels=scores_plot)) %>%
    mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    ungroup() %>%
    pivot_wider(names_from=score, values_from=cindex) %>% 
    mutate(id = row_number()) %>%
    mutate(delta = `Age+Sex+MedicalHistory`-`Age+Sex`) %>%
    group_by(endpoint, phecode_string, phecode_category) %>%
    summarise(delta = median(delta)) %>%
    mutate(pos = case_when(delta>=0 ~ "pos", delta < 0 ~"neg")) %>%
    mutate(endpoint = fct_reorder(endpoint, delta)) %>%
    mutate(highlight = case_when(endpoint %in% endpoint_selection ~ "YES", TRUE ~ "NO")) %>%# %>% filter(endpoint %in% endpoint_sample)
    mutate(phecode_category = factor(phecode_category, levels=categories_sorted))

endpoint_order = (temp %>% arrange(delta))$endpoint

temp = temp %>% mutate(endpoint = factor(endpoint, levels=endpoint_order))

ggplot(temp) + 
    geom_point(aes(x=endpoint, y=delta, color=highlight), size=0.5) +
    geom_segment(aes(x=endpoint, xend=endpoint, y=0, yend=delta, color=highlight, size=highlight), alpha=0.5)+#+
    scale_color_manual(values=c("NO"="black", "YES"="firebrick"))+
    #scale_alpha_manual(values=c("NO"=0.3, "YES"=0.7))+
    scale_size_manual(values=c("NO"=0.1, "YES"=0.5))+
    #scale_colour_manual(values = c("pos"="forestgreen", "neg" = "firebrick")) + 
    coord_cartesian(ylim=c(0, NA), clip = "off")+
    scale_y_continuous(expand=c(0, 0))+
    scale_x_discrete(expand=expansion(add=8))+
    facet_grid(~phecode_category, scale="free_x", space="free_x")+#, switch=TRUE)+
    theme(axis.title.x=element_blank(),
        axis.text.x=element_blank(),
        axis.ticks.x=element_blank(),
     strip.text = element_text(angle=270)) + 
    theme(legend.position="none")
    
    #geom_ribbon(aes(x=id, ymin=AgeSex, ymax=`Age+Sex+MedicalHistory`), fill="red", alpha=0.2)
#geom_violin(size=0.1)
# Out:
# `summarise()` has grouped output by 'endpoint', 'phecode_string'. You can override using the `.groups` argument.
# plot without title

# %%
plot_width = 8.25; plot_height=2; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

scores_plot = c("MedicalHistory", "Age+Sex", "Age+Sex+MedicalHistory")#, "AgeSexMedicalHistory")

temp = benchmark_endpoints %>% 
    filter(score %in% scores_plot) %>% 
    mutate(score = factor(score, levels=scores_plot)) %>%
    mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    group_by(endpoint, score, phecode_string, phecode_category) %>%
    ungroup() %>%
    pivot_wider(names_from=score, values_from=cindex) %>% 
    mutate(id = row_number()) %>%
    mutate(delta = `Age+Sex+MedicalHistory`-`Age+Sex`) %>%
    #mutate(delta_int = `Age+Sex+MedicalHistory`-`Age+Sex+MedicalHistory`) %>%
    mutate(pos = case_when(delta>=0 ~ "pos", delta < 0 ~"neg")) %>%
    mutate(endpoint = fct_reorder(endpoint, delta)) %>%
    mutate(highlight = case_when(endpoint %in% endpoint_selection ~ "YES", TRUE ~ "NO")) %>%# %>% filter(endpoint %in% endpoint_sample)
    mutate(phecode_category = factor(phecode_category, levels=categories_sorted)) %>%
    filter(endpoint %in% endpoint_selection)
    #%>%
    #summarise(cindex = mean(cindex)) 
temp
# Out:
#      endpoint      iteration time phecode phecode_string
# 1    phecode_280    0        10   280     Substance related disorders
# 2    phecode_280    1        10   280     Substance related disorders
# 3    phecode_280    2        10   280     Substance related disorders
# 4    phecode_280    3        10   280     Substance related disorders
# 5    phecode_280    4        10   280     Substance related disorders
# 6    phecode_280    5        10   280     Substance related disorders
# 7    phecode_280    6        10   280     Substance related disorders
# 8    phecode_280    7        10   280     Substance related disorders
# 9    phecode_280    8        10   280     Substance related disorders
# 10   phecode_280    9        10   280     Substance related disorders
# 11   phecode_280   10        10   280     Substance related disorders
# 12   phecode_280   11        10   280     Substance related disorders
# 13   phecode_280   12        10   280     Substance related disorders
# 14   phecode_280   13        10   280     Substance related disorders
# 15   phecode_280   14        10   280     Substance related disorders
# 16   phecode_280   15        10   280     Substance related disorders
# 17   phecode_280   16        10   280     Substance related disorders
# 18   phecode_280   17        10   280     Substance related disorders
# 19   phecode_280   18        10   280     Substance related disorders
# 20   phecode_280   19        10   280     Substance related disorders
# 21   phecode_280   20        10   280     Substance related disorders
# 22   phecode_280   21        10   280     Substance related disorders
# 23   phecode_280   22        10   280     Substance related disorders
# 24   phecode_280   23        10   280     Substance related disorders
# 25   phecode_280   24        10   280     Substance related disorders
# 26   phecode_280   25        10   280     Substance related disorders
# 27   phecode_280   26        10   280     Substance related disorders
# 28   phecode_280   27        10   280     Substance related disorders
# 29   phecode_280   28        10   280     Substance related disorders
# 30   phecode_280   29        10   280     Substance related disorders
# ⋮    ⋮             ⋮         ⋮    ⋮       ⋮
# 5871 phecode_308-7 70        10   308.7   Restlessness and agitation*
# 5872 phecode_308-7 71        10   308.7   Restlessness and agitation*
# 5873 phecode_308-7 72        10   308.7   Restlessness and agitation*
# 5874 phecode_308-7 73        10   308.7   Restlessness and agitation*
# 5875 phecode_308-7 74        10   308.7   Restlessness and agitation*
# 5876 phecode_308-7 75        10   308.7   Restlessness and agitation*
# 5877 phecode_308-7 76        10   308.7   Restlessness and agitation*
# 5878 phecode_308-7 77        10   308.7   Restlessness and agitation*
# 5879 phecode_308-7 78        10   308.7   Restlessness and agitation*
# 5880 phecode_308-7 79        10   308.7   Restlessness and agitation*
# 5881 phecode_308-7 80        10   308.7   Restlessness and agitation*
# 5882 phecode_308-7 81        10   308.7   Restlessness and agitation*
# 5883 phecode_308-7 82        10   308.7   Restlessness and agitation*
# 5884 phecode_308-7 83        10   308.7   Restlessness and agitation*
# 5885 phecode_308-7 84        10   308.7   Restlessness and agitation*
# 5886 phecode_308-7 85        10   308.7   Restlessness and agitation*
# 5887 phecode_308-7 86        10   308.7   Restlessness and agitation*
# 5888 phecode_308-7 87        10   308.7   Restlessness and agitation*
# 5889 phecode_308-7 88        10   308.7   Restlessness and agitation*
# 5890 phecode_308-7 89        10   308.7   Restlessness and agitation*
# 5891 phecode_308-7 90        10   308.7   Restlessness and agitation*
# 5892 phecode_308-7 91        10   308.7   Restlessness and agitation*
# 5893 phecode_308-7 92        10   308.7   Restlessness and agitation*
# 5894 phecode_308-7 93        10   308.7   Restlessness and agitation*
# 5895 phecode_308-7 94        10   308.7   Restlessness and agitation*
# 5896 phecode_308-7 95        10   308.7   Restlessness and agitation*
# 5897 phecode_308-7 96        10   308.7   Restlessness and agitation*
# 5898 phecode_308-7 97        10   308.7   Restlessness and agitation*
# 5899 phecode_308-7 98        10   308.7   Restlessness and agitation*
# 5900 phecode_308-7 99        10   308.7   Restlessness and agitation*
#      phecode_category sex  ICD10_only phecode_top leaf
# 1    Mental           Both 0          280         0
# 2    Mental           Both 0          280         0
# 3    Mental           Both 0          280         0
# 4    Mental           Both 0          280         0
# 5    Mental           Both 0          280         0
# 6    Mental           Both 0          280         0
# 7    Mental           Both 0          280         0
# 8    Mental           Both 0          280         0
# 9    Mental           Both 0          280         0
# 10   Mental           Both 0          280         0
# 11   Mental           Both 0          280         0
# 12   Mental           Both 0          280         0
# 13   Mental           Both 0          280         0
# 14   Mental           Both 0          280         0
# 15   Mental           Both 0          280         0
# 16   Mental           Both 0          280         0
# 17   Mental           Both 0          280         0
# 18   Mental           Both 0          280         0
# 19   Mental           Both 0          280         0
# 20   Mental           Both 0          280         0
# 21   Mental           Both 0          280         0
# 22   Mental           Both 0          280         0
# 23   Mental           Both 0          280         0
# 24   Mental           Both 0          280         0
# 25   Mental           Both 0          280         0
# 26   Mental           Both 0          280         0
# 27   Mental           Both 0          280         0
# 28   Mental           Both 0          280         0
# 29   Mental           Both 0          280         0
# 30   Mental           Both 0          280         0
# ⋮    ⋮                ⋮    ⋮          ⋮           ⋮
# 5871 Mental           Both 1          308         1
# 5872 Mental           Both 1          308         1
# 5873 Mental           Both 1          308         1
# 5874 Mental           Both 1          308         1
# 5875 Mental           Both 1          308         1
# 5876 Mental           Both 1          308         1
# 5877 Mental           Both 1          308         1
# 5878 Mental           Both 1          308         1
# 5879 Mental           Both 1          308         1
# 5880 Mental           Both 1          308         1
# 5881 Mental           Both 1          308         1
# 5882 Mental           Both 1          308         1
# 5883 Mental           Both 1          308         1
# 5884 Mental           Both 1          308         1
# 5885 Mental           Both 1          308         1
# 5886 Mental           Both 1          308         1
# 5887 Mental           Both 1          308         1
# 5888 Mental           Both 1          308         1
# 5889 Mental           Both 1          308         1
# 5890 Mental           Both 1          308         1
# 5891 Mental           Both 1          308         1
# 5892 Mental           Both 1          308         1
# 5893 Mental           Both 1          308         1
# 5894 Mental           Both 1          308         1
# 5895 Mental           Both 1          308         1
# 5896 Mental           Both 1          308         1
# 5897 Mental           Both 1          308         1
# 5898 Mental           Both 1          308         1
# 5899 Mental           Both 1          308         1
# 5900 Mental           Both 1          308         1
#      name                        Age+Sex   MedicalHistory
# 1    Substance related disorders 0.5630118 0.7402711
# 2    Substance related disorders 0.5624268 0.7421240
# 3    Substance related disorders 0.5654692 0.7408108
# 4    Substance related disorders 0.5628547 0.7386107
# 5    Substance related disorders 0.5652522 0.7388426
# 6    Substance related disorders 0.5658761 0.7406192
# 7    Substance related disorders 0.5620207 0.7392238
# 8    Substance related disorders 0.5628689 0.7394081
# 9    Substance related disorders 0.5657679 0.7389605
# 10   Substance related disorders 0.5659530 0.7398471
# 11   Substance related disorders 0.5643231 0.7379281
# 12   Substance related disorders 0.5643538 0.7411540
# 13   Substance related disorders 0.5656772 0.7381086
# 14   Substance related disorders 0.5645655 0.7387474
# 15   Substance related disorders 0.5621380 0.7357795
# 16   Substance related disorders 0.5643284 0.7405098
# 17   Substance related disorders 0.5665092 0.7402352
# 18   Substance related disorders 0.5618300 0.7374447
# 19   Substance related disorders 0.5676890 0.7398003
# 20   Substance related disorders 0.5663404 0.7401070
# 21   Substance related disorders 0.5657265 0.7394343
# 22   Substance related disorders 0.5656188 0.7417279
# 23   Substance related disorders 0.5657808 0.7406717
# 24   Substance related disorders 0.5634977 0.7386333
# 25   Substance related disorders 0.5665340 0.7389559
# 26   Substance related disorders 0.5634507 0.7378822
# 27   Substance related disorders 0.5668936 0.7405409
# 28   Substance related disorders 0.5648266 0.7398048
# 29   Substance related disorders 0.5647191 0.7410441
# 30   Substance related disorders 0.5659325 0.7424108
# ⋮    ⋮                           ⋮         ⋮
# 5871 Restlessness and agitation* 0.5458235 0.7791882
# 5872 Restlessness and agitation* 0.5428121 0.7729404
# 5873 Restlessness and agitation* 0.5441235 0.7873729
# 5874 Restlessness and agitation* 0.5520760 0.7811730
# 5875 Restlessness and agitation* 0.5235472 0.7753372
# 5876 Restlessness and agitation* 0.5545972 0.7773700
# 5877 Restlessness and agitation* 0.5299268 0.7825869
# 5878 Restlessness and agitation* 0.5386146 0.7782605
# 5879 Restlessness and agitation* 0.5484645 0.7857432
# 5880 Restlessness and agitation* 0.5343521 0.7694758
# 5881 Restlessness and agitation* 0.5439151 0.7853125
# 5882 Restlessness and agitation* 0.5345286 0.7811899
# 5883 Restlessness and agitation* 0.5244701 0.7879131
# 5884 Restlessness and agitation* 0.5467774 0.7697301
# 5885 Restlessness and agitation* 0.5450684 0.7790535
# 5886 Restlessness and agitation* 0.5408177 0.7693453
# 5887 Restlessness and agitation* 0.5290521 0.7812761
# 5888 Restlessness and agitation* 0.5317065 0.7788139
# 5889 Restlessness and agitation* 0.5309717 0.7881985
# 5890 Restlessness and agitation* 0.5444392 0.7765720
# 5891 Restlessness and agitation* 0.5560566 0.7817203
# 5892 Restlessness and agitation* 0.5369140 0.7844304
# 5893 Restlessness and agitation* 0.5393005 0.7762977
# 5894 Restlessness and agitation* 0.5373534 0.7782993
# 5895 Restlessness and agitation* 0.5282305 0.7761709
# 5896 Restlessness and agitation* 0.5502041 0.7735380
# 5897 Restlessness and agitation* 0.5359612 0.7858585
# 5898 Restlessness and agitation* 0.5443863 0.7641107
# 5899 Restlessness and agitation* 0.5311812 0.7799864
# 5900 Restlessness and agitation* 0.5308973 0.7700866
#      Age+Sex+MedicalHistory id    delta     pos highlight
# 1    0.7406577              35501 0.1776459 pos YES
# 2    0.7424794              35502 0.1800526 pos YES
# 3    0.7410656              35503 0.1755964 pos YES
# 4    0.7388975              35504 0.1760428 pos YES
# 5    0.7392140              35505 0.1739618 pos YES
# 6    0.7412422              35506 0.1753661 pos YES
# 7    0.7400905              35507 0.1780699 pos YES
# 8    0.7394993              35508 0.1766304 pos YES
# 9    0.7394663              35509 0.1736984 pos YES
# 10   0.7403172              35510 0.1743641 pos YES
# 11   0.7383468              35511 0.1740237 pos YES
# 12   0.7418400              35512 0.1774861 pos YES
# 13   0.7385056              35513 0.1728283 pos YES
# 14   0.7391047              35514 0.1745393 pos YES
# 15   0.7360291              35515 0.1738911 pos YES
# 16   0.7408637              35516 0.1765353 pos YES
# 17   0.7410061              35517 0.1744969 pos YES
# 18   0.7378292              35518 0.1759992 pos YES
# 19   0.7402059              35519 0.1725170 pos YES
# 20   0.7405508              35520 0.1742105 pos YES
# 21   0.7400279              35521 0.1743014 pos YES
# 22   0.7421175              35522 0.1764987 pos YES
# 23   0.7411187              35523 0.1753379 pos YES
# 24   0.7387100              35524 0.1752123 pos YES
# 25   0.7392585              35525 0.1727246 pos YES
# 26   0.7383757              35526 0.1749250 pos YES
# 27   0.7410953              35527 0.1742018 pos YES
# 28   0.7401431              35528 0.1753165 pos YES
# 29   0.7416589              35529 0.1769398 pos YES
# 30   0.7428644              35530 0.1769320 pos YES
# ⋮    ⋮                      ⋮     ⋮         ⋮   ⋮
# 5871 0.7783771              41371 0.2325536 pos YES
# 5872 0.7718990              41372 0.2290869 pos YES
# 5873 0.7868274              41373 0.2427040 pos YES
# 5874 0.7801783              41374 0.2281023 pos YES
# 5875 0.7732763              41375 0.2497291 pos YES
# 5876 0.7762336              41376 0.2216365 pos YES
# 5877 0.7803910              41377 0.2504642 pos YES
# 5878 0.7774128              41378 0.2387982 pos YES
# 5879 0.7848060              41379 0.2363414 pos YES
# 5880 0.7678515              41380 0.2334994 pos YES
# 5881 0.7846741              41381 0.2407591 pos YES
# 5882 0.7794559              41382 0.2449272 pos YES
# 5883 0.7854754              41383 0.2610053 pos YES
# 5884 0.7692315              41384 0.2224541 pos YES
# 5885 0.7780704              41385 0.2330020 pos YES
# 5886 0.7681147              41386 0.2272970 pos YES
# 5887 0.7802133              41387 0.2511612 pos YES
# 5888 0.7771888              41388 0.2454823 pos YES
# 5889 0.7866724              41389 0.2557007 pos YES
# 5890 0.7753499              41390 0.2309108 pos YES
# 5891 0.7819928              41391 0.2259362 pos YES
# 5892 0.7834589              41392 0.2465449 pos YES
# 5893 0.7742999              41393 0.2349994 pos YES
# 5894 0.7766717              41394 0.2393183 pos YES
# 5895 0.7742017              41395 0.2459712 pos YES
# 5896 0.7733280              41396 0.2231239 pos YES
# 5897 0.7841614              41397 0.2482002 pos YES
# 5898 0.7633987              41398 0.2190124 pos YES
# 5899 0.7774743              41399 0.2462931 pos YES
# 5900 0.7677459              41400 0.2368486 pos YES

# %%
library(ggdist)
# Out:
# Warning message:
# “package ‘ggdist’ was built under R version 4.0.5”

# %%
base_size = 8
title_size = 10
facet_size = 9
geom_text_size=3
theme_set(theme_classic(base_size = base_size) + 
          theme(strip.background = element_blank(), plot.title=element_text(size=title_size, hjust=0), 
                strip.text.x = element_text(size = facet_size),axis.title=element_text(size=10), axis.text=element_text(size=8, color="black"),
                legend.position="bottom", axis.line = element_line(size = 0.2), axis.ticks=element_line(size=0.2), panel.grid.major=element_line()))

# %%
abs = ggplot(temp %>% group_by(endpoint) %>% summarise(m_asm=median(`Age+Sex+MedicalHistory`), m_as=median(`Age+Sex`))) + 
    #geom_violin(aes(x=fct_rev(endpoint), y=delta), size=0.5) +
    labs(y="Concordance Index", x="Endpoint")+
    #stat_pointinterval(aes(x=fct_rev(endpoint), y=`Age+Sex`), size=1, color="black", alpha=0.3)+
    #stat_pointinterval(aes(x=fct_rev(endpoint), y=`Age+Sex+MedicalHistory`), size=1, color="#023768", alpha=0.5)+
    geom_point(aes(x=fct_rev(endpoint), y=m_as), size=1, color="black", alpha=0.7)+
    geom_point(aes(x=fct_rev(endpoint), y=m_asm), size=1, color="#023768", alpha=0.7)+
    geom_segment(aes(x=endpoint, xend=endpoint, y=m_as+0.005, yend=m_asm-0.005), alpha=0.4)+#+
    #scale_color_manual(values=c("NO"="black", "YES"="firebrick"))+
    #scale_alpha_manual(values=c("NO"=0.3, "YES"=0.7))+
    #scale_size_manual(values=c("NO"=0.1, "YES"=0.5))+
    #scale_colour_manual(values = c("pos"="forestgreen", "neg" = "firebrick")) + 
    coord_cartesian(ylim=c(0, NA), clip = "off")+
    scale_x_discrete(labels=endpoint_map) +
    #scale_y_continuous(expand=c(0, 0))+
    #theme(axis.title.x=element_blank(),
     #   axis.text.x=element_blank(),
      #  axis.ticks.x=element_blank(),
    coord_flip()+
     theme(strip.text = element_text(angle=270)) + 
    theme(legend.position="none")
    
    #geom_ribbon(aes(x=id, ymin=AgeSex, ymax=`Age+Sex+MedicalHistory`), fill="red", alpha=0.2)
#geom_violin(size=0.1)
abs
# Out:
# Coordinate system already present. Adding new coordinate system, which will replace the existing one.
# plot without title

# %%
rel = ggplot(temp) + 
    #geom_violin(aes(x=fct_rev(endpoint), y=delta), size=0.5) +
    labs(y="Difference in Concordance Index")+
    stat_pointinterval(aes(x=fct_rev(endpoint), y=delta), size=0.5)+
    #geom_segment(aes(x=endpoint, xend=endpoint, y=0, yend=delta, color=highlight, size=highlight), alpha=0.5)+#+
    #scale_color_manual(values=c("NO"="black", "YES"="firebrick"))+
    #scale_alpha_manual(values=c("NO"=0.3, "YES"=0.7))+
    #scale_size_manual(values=c("NO"=0.1, "YES"=0.5))+
    #scale_colour_manual(values = c("pos"="forestgreen", "neg" = "firebrick")) + 
    coord_cartesian(ylim=c(0, NA), clip = "off")+
    #scale_y_continuous(expand=c(0, 0))+
    theme(axis.title.y=element_blank(),
        axis.text.y=element_blank(),
       axis.ticks.y=element_blank()) + 
    coord_flip()+
     theme(strip.text = element_text(angle=270)) + 
    theme(legend.position="none")
    
    #geom_ribbon(aes(x=id, ymin=AgeSex, ymax=`Age+Sex+MedicalHistory`), fill="red", alpha=0.2)
#geom_violin(size=0.1)
# Out:
# Coordinate system already present. Adding new coordinate system, which will replace the existing one.

# %%
plot_width = 8.25; plot_height=6.5; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)
abs|rel
# Out:
# plot without title

# %%
ggplot(temp) + 
    geom_point(aes(x=endpoint, y=delta, color=highlight), size=0.5) +
    geom_segment(aes(x=endpoint, xend=endpoint, y=0, yend=delta, color=highlight, size=highlight), alpha=0.5)+#+
    scale_color_manual(values=c("NO"="black", "YES"="firebrick"))+
    #scale_alpha_manual(values=c("NO"=0.3, "YES"=0.7))+
    scale_size_manual(values=c("NO"=0.1, "YES"=0.5))+
    #scale_colour_manual(values = c("pos"="forestgreen", "neg" = "firebrick")) + 
    coord_cartesian(ylim=c(0, NA), clip = "off")+
    scale_y_continuous(expand=c(0, 0))+
    scale_x_discrete(expand=expansion(add=8))+
    facet_grid(~phecode_category, scale="free_x", space="free_x")+#, switch=TRUE)+
    theme(axis.title.x=element_blank(),
        axis.text.x=element_blank(),
        axis.ticks.x=element_blank(),
     strip.text = element_text(angle=270)) + 
    theme(legend.position="none")
    
    #geom_ribbon(aes(x=id, ymin=AgeSex, ymax=`Age+Sex+MedicalHistory`), fill="red", alpha=0.2)
#geom_violin(size=0.1)
# Out:
# plot without title

# %%
library(ggdist)

# %%
table_2 = benchmark_endpoints %>% 
    filter(score %in% scores_plot) %>% 
    mutate(score = factor(score, levels=scores_plot)) %>%
    mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    group_by(endpoint, score, phecode_string, phecode_category) %>%
    pivot_wider(names_from=score, values_from=cindex) %>% 
    mutate(id = row_number()) %>%
    mutate(delta = `Age+Sex+MedicalHistory`-`Age+Sex`) %>%
    #select(endpoint, iteration, phecode_string, phecode_category, sex, `Age+Sex`, `Age+Sex+MedicalHistory`, delta) %>%
    pivot_longer(all_of(c("Age+Sex", "Age+Sex+MedicalHistory", "delta")), names_to="type", values_to="cindex") %>%
    group_by(endpoint, phecode_string, phecode_category, type) %>%
    median_qi(cindex) %>%
    #ungroup() %>%
    mutate(agg = glue("{round(cindex, 3)} ({round(.lower, 3)}, {round(.upper, 3)})")) %>%
    ungroup() %>% select(endpoint, phecode_string, phecode_category, type, agg) %>%
    pivot_wider(names_from=type, values_from=agg)
    #mutate(pos = case_when(delta>=0 ~ "pos", delta < 0 ~"neg")) %>%
    #mutate(endpoint = fct_reorder(endpoint, delta))# %>% filter(endpoint %in% endpoint_sample)

# %%
table_2 %>% 
    select(all_of(c("endpoint", "phecode_string", "Age+Sex", 'Age+Sex+MedicalHistory', "delta"))) %>%
    mutate(endpoint = factor(endpoint, levels = endpoint_order)) %>% 
    filter(endpoint %in% endpoint_selection) %>%
    arrange(endpoint)
# Out:
#    endpoint       phecode_string
# 1  phecode_092-2  Sepsis
# 2  phecode_105    Malignant neoplasm of the breast
# 3  phecode_164    Anemia
# 4  phecode_287-5  Drug-induced psychotic disorder
# 5  phecode_328    Dementias and cerebral degeneration
# 6  phecode_404    Ischemic heart disease
# 7  phecode_424    Heart failure
# 8  phecode_440-11 Deep vein thrombosis [DVT]
# 9  phecode_468    Pneumonia
# 10 phecode_474    Chronic obstructive pulmonary disease [COPD]
# 11 phecode_542-1  Fibrosis and cirrhosis of liver
# 12 phecode_583    Chronic kidney disease
# 13 phecode_705-1  Rheumatoid arthritis
# 14 phecode_908-1  Preeclampsia and eclampsia
# 15 phecode_976    Adverse effect of anesthesia
#    Age+Sex              Age+Sex+MedicalHistory delta
# 1  0.654 (0.651, 0.659) 0.714 (0.711, 0.718)   0.06 (0.056, 0.063)
# 2  0.757 (0.754, 0.759) 0.756 (0.754, 0.758)   -0.001 (-0.002, 0)
# 3  0.599 (0.596, 0.601) 0.674 (0.672, 0.676)   0.075 (0.072, 0.077)
# 4  0.837 (0.83, 0.843)  0.941 (0.938, 0.945)   0.104 (0.098, 0.11)
# 5  0.637 (0.631, 0.642) 0.766 (0.761, 0.769)   0.129 (0.123, 0.134)
# 6  0.7 (0.699, 0.702)   0.741 (0.739, 0.743)   0.04 (0.039, 0.042)
# 7  0.655 (0.651, 0.659) 0.786 (0.783, 0.789)   0.132 (0.128, 0.135)
# 8  0.617 (0.608, 0.629) 0.892 (0.888, 0.897)   0.275 (0.265, 0.285)
# 9  0.657 (0.654, 0.66)  0.725 (0.723, 0.728)   0.069 (0.067, 0.071)
# 10 0.597 (0.595, 0.599) 0.789 (0.788, 0.791)   0.193 (0.191, 0.195)
# 11 0.645 (0.635, 0.654) 0.798 (0.79, 0.807)    0.154 (0.142, 0.167)
# 12 0.656 (0.654, 0.658) 0.784 (0.782, 0.787)   0.129 (0.126, 0.131)
# 13 0.591 (0.587, 0.595) 0.699 (0.695, 0.704)   0.108 (0.103, 0.112)
# 14 0.594 (0.588, 0.599) 0.89 (0.887, 0.892)    0.295 (0.291, 0.301)
# 15 0.558 (0.551, 0.565) 0.889 (0.886, 0.892)   0.331 (0.323, 0.339)

# %%
options(pillar.print_max = Inf)
table_2 %>% 
    select(all_of(c("phecode_category", "endpoint", "phecode_string", "Age+Sex", 'Age+Sex+MedicalHistory', "delta"))) %>%
    mutate(endpoint = factor(endpoint, levels = endpoint_order)) %>% 
    #filter(endpoint %in% endpoint_selection) %>%
    arrange(endpoint) %>% 
    write_csv("outputs/SupplTable1_DiscriminativePerformanceAll.csv")

# %%
table_2 %>% filter(endpoint %in% endpoint_selection) %>% arrange(as.character(endpoint))
# Out:
#    endpoint       phecode_string                               phecode_category
# 1  phecode_092-2  Sepsis                                       ID
# 2  phecode_105    Malignant neoplasm of the breast             Neoplasms
# 3  phecode_164    Anemia                                       Blood
# 4  phecode_287-5  Drug-induced psychotic disorder              Mental
# 5  phecode_328    Dementias and cerebral degeneration          Neuro
# 6  phecode_404    Ischemic heart disease                       Cardio
# 7  phecode_424    Heart failure                                Cardio
# 8  phecode_440-11 Deep vein thrombosis [DVT]                   Cardio
# 9  phecode_468    Pneumonia                                    Resp
# 10 phecode_474    Chronic obstructive pulmonary disease [COPD] Resp
# 11 phecode_542-1  Fibrosis and cirrhosis of liver              GI
# 12 phecode_583    Chronic kidney disease                       Genitourinary
# 13 phecode_705-1  Rheumatoid arthritis                         Musc/Skel
# 14 phecode_908-1  Preeclampsia and eclampsia                   Preg
# 15 phecode_976    Adverse effect of anesthesia                 Rx
#    Age+Sex              Age+Sex+MedicalHistory delta
# 1  0.654 (0.651, 0.659) 0.714 (0.711, 0.718)   0.06 (0.056, 0.063)
# 2  0.757 (0.754, 0.759) 0.756 (0.754, 0.758)   -0.001 (-0.002, 0)
# 3  0.599 (0.596, 0.601) 0.674 (0.672, 0.676)   0.075 (0.072, 0.077)
# 4  0.837 (0.83, 0.843)  0.941 (0.938, 0.945)   0.104 (0.098, 0.11)
# 5  0.637 (0.631, 0.642) 0.766 (0.761, 0.769)   0.129 (0.123, 0.134)
# 6  0.7 (0.699, 0.702)   0.741 (0.739, 0.743)   0.04 (0.039, 0.042)
# 7  0.655 (0.651, 0.659) 0.786 (0.783, 0.789)   0.132 (0.128, 0.135)
# 8  0.617 (0.608, 0.629) 0.892 (0.888, 0.897)   0.275 (0.265, 0.285)
# 9  0.657 (0.654, 0.66)  0.725 (0.723, 0.728)   0.069 (0.067, 0.071)
# 10 0.597 (0.595, 0.599) 0.789 (0.788, 0.791)   0.193 (0.191, 0.195)
# 11 0.645 (0.635, 0.654) 0.798 (0.79, 0.807)    0.154 (0.142, 0.167)
# 12 0.656 (0.654, 0.658) 0.784 (0.782, 0.787)   0.129 (0.126, 0.131)
# 13 0.591 (0.587, 0.595) 0.699 (0.695, 0.704)   0.108 (0.103, 0.112)
# 14 0.594 (0.588, 0.599) 0.89 (0.887, 0.892)    0.295 (0.291, 0.301)
# 15 0.558 (0.551, 0.565) 0.889 (0.886, 0.892)   0.331 (0.323, 0.339)
