# %% [markdown]
# # Benchmarks

# %% [markdown]
# ## Initialize

# %%
#library(Rmisc)
library(dtplyr)
library(tidyverse)
library(glue)
library(arrow)
library(patchwork)
library(data.table)
library("jsonlite")
library(ggthemes)

# %%
if (grepl("sc", Sys.info()[["nodename"]], fixed=TRUE)) {
    base_path = "/sc-projects/sc-proj-ukb-cvd"
} else {
    base_path = "/data/analysis/ag-reils/ag-reils-shared/cardioRS"}
print(base_path)

project_label="22_medical_records"
project_path = glue("{base_path}/results/projects/{project_label}")
figure_path = glue("{project_path}/figures")
output_path = glue("{project_path}/data")

experiment = 220413
experiment_path = glue("{output_path}/{experiment}")
# Out:
# [1] "/sc-projects/sc-proj-ukb-cvd"

# %%
base_size = 8
title_size = 10
facet_size = 10
geom_text_size=3
theme_set(theme_classic(base_size = base_size) + 
          theme(strip.background = element_blank(), plot.title=element_text(size=title_size, hjust=0), 
                strip.text.x = element_text(size = facet_size),axis.title=element_text(size=10), axis.text=element_text(size=8, color="black"),
                legend.position="bottom", axis.line = element_line(size = 0.2), axis.ticks=element_line(size=0.2), panel.grid.major=element_line()))

# %%
colors_dict = read_json("colors.json")
color_map <- c(
    "Identity(AgeSex)+MLP" = colors_dict$pastel$red$mid,
    "Identity(Records)+MLP" = colors_dict$pastel$red$mid,
    "GNN(Records)+MLP" = colors_dict$pastel$red$mid,
    "Identity(AgeSex+Records)+MLP" = colors_dict$pastel$red$mid,
    "GNN(AgeSex+Records)+MLP" = colors_dict$pastel$red$mid
)

# %%
endpoint_defs = arrow::read_feather(glue("{output_path}/phecode_defs_220306.feather")) %>% arrange(endpoint)

# %%
endpoint_map = endpoint_defs$phecode_string
names(endpoint_map) =  endpoint_defs$endpoint
#endpoint_order_freq = (outcome_freq %>% arrange(desc(freq)))$endpoint

# %%
endpoint_order = (endpoint_defs %>% arrange(as.numeric(phecode)))$endpoint

# %%
endpoint_selection = c(
    "phecode_008",
    "phecode_092-2",
    "phecode_105",
    "phecode_107-2",
    "phecode_164",
    "phecode_202-2",
    "phecode_284",
    "phecode_328",
    "phecode_371",
    "phecode_404",
    "phecode_424",
    "phecode_440-11",
    "phecode_468",
    "phecode_474",
    "phecode_522-1",
    "phecode_542-1",
    "phecode_581-1",
    "phecode_583",
    "phecode_705-1",
    "OMOP_4306655"
    )

# %% [markdown]
# ## Load data

# %% [markdown]
# # Load Benchmarks

# %%
name = "hrs_endpoints"
hrs_endpoints = arrow::read_feather(glue("{experiment_path}/{name}.feather"), col_select=c("endpoint", "score", "partition", "hrs_mh", "hrs_mh_age", "hrs_mh_sex")) %>% left_join(endpoint_defs)
# Out:
# Joining, by = "endpoint"

# %%
hrs_endpoints
# Out:
#        endpoint     score                            partition hrs_mh
# 1      OMOP_4306655 Age+Sex+MedicalHistory           0         4.543129
# 2      OMOP_4306655 Age+Sex+MedicalHistory           1         4.626850
# 3      OMOP_4306655 Age+Sex+MedicalHistory           2         4.587563
# 4      OMOP_4306655 Age+Sex+MedicalHistory           3         4.625650
# 5      OMOP_4306655 Age+Sex+MedicalHistory           4         4.494688
# 6      OMOP_4306655 Age+Sex+MedicalHistory           5         4.660579
# 7      OMOP_4306655 Age+Sex+MedicalHistory           6         4.539814
# 8      OMOP_4306655 Age+Sex+MedicalHistory           7         4.780453
# 9      OMOP_4306655 Age+Sex+MedicalHistory           8         4.517744
# 10     OMOP_4306655 Age+Sex+MedicalHistory           9         4.769463
# 11     OMOP_4306655 Age+Sex+MedicalHistory           10        4.359181
# 12     OMOP_4306655 Age+Sex+MedicalHistory           11        4.514668
# 13     OMOP_4306655 Age+Sex+MedicalHistory           12        4.622716
# 14     OMOP_4306655 Age+Sex+MedicalHistory           13        4.712837
# 15     OMOP_4306655 Age+Sex+MedicalHistory           14        4.697196
# 16     OMOP_4306655 Age+Sex+MedicalHistory           15        4.642005
# 17     OMOP_4306655 Age+Sex+MedicalHistory           16        4.712686
# 18     OMOP_4306655 Age+Sex+MedicalHistory           17        4.775385
# 19     OMOP_4306655 Age+Sex+MedicalHistory           18        4.575772
# 20     OMOP_4306655 Age+Sex+MedicalHistory           19        4.855588
# 21     OMOP_4306655 Age+Sex+MedicalHistory           20        4.740240
# 22     OMOP_4306655 Age+Sex+MedicalHistory           21        4.739648
# 23     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 0         4.641458
# 24     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 1         4.467356
# 25     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 2         4.463099
# 26     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 3         4.558575
# 27     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 4         4.570274
# 28     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 5         4.533612
# 29     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 6         4.407513
# 30     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 7         4.621781
# ⋮      ⋮            ⋮                                ⋮         ⋮
# 103921 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 14        3.281990
# 103922 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 15        3.453482
# 103923 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 16        3.140458
# 103924 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 17        3.153143
# 103925 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 18        3.293742
# 103926 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 19        3.035455
# 103927 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 20        3.183346
# 103928 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 21        3.196434
# 103929 phecode_979  MedicalHistory                   0         3.285301
# 103930 phecode_979  MedicalHistory                   1         3.230414
# 103931 phecode_979  MedicalHistory                   2         3.854825
# 103932 phecode_979  MedicalHistory                   3         3.512871
# 103933 phecode_979  MedicalHistory                   4         3.447379
# 103934 phecode_979  MedicalHistory                   5         3.054510
# 103935 phecode_979  MedicalHistory                   6         3.085640
# 103936 phecode_979  MedicalHistory                   7         3.372215
# 103937 phecode_979  MedicalHistory                   8         3.115814
# 103938 phecode_979  MedicalHistory                   9         2.991610
# 103939 phecode_979  MedicalHistory                   10        3.182099
# 103940 phecode_979  MedicalHistory                   11        3.322076
# 103941 phecode_979  MedicalHistory                   12        3.257155
# 103942 phecode_979  MedicalHistory                   13        3.321948
# 103943 phecode_979  MedicalHistory                   14        3.144321
# 103944 phecode_979  MedicalHistory                   15        3.386191
# 103945 phecode_979  MedicalHistory                   16        3.080827
# 103946 phecode_979  MedicalHistory                   17        3.104220
# 103947 phecode_979  MedicalHistory                   18        3.213847
# 103948 phecode_979  MedicalHistory                   19        2.956662
# 103949 phecode_979  MedicalHistory                   20        3.125299
# 103950 phecode_979  MedicalHistory                   21        3.107505
#        hrs_mh_age hrs_mh_sex phecode phecode_string    phecode_category sex
# 1             NA        NA   4306655 All-Cause Death   Death            Both
# 103944       NA          NA  979     Transplated organ Stat             Both
# 103945       NA          NA  979     Transplated organ Stat             Both
# 103946       NA          NA  979     Transplated organ Stat             Both
# 103947       NA          NA  979     Transplated organ Stat             Both
# 103948       NA          NA  979     Transplated organ Stat             Both
# 103949       NA          NA  979     Transplated organ Stat             Both
# 103950       NA          NA  979     Transplated organ Stat             Both
#        ICD10_only phecode_top leaf
# 1      NA         NA          NA
# 2      NA         NA          NA
# 3      NA         NA          NA
# 4      NA         NA          NA
# 5      NA         NA          NA
# 6      NA         NA          NA
# 7      NA         NA          NA
# 8      NA         NA          NA
# 9      NA         NA          NA
# 10     NA         NA          NA
# 11     NA         NA          NA
# 12     NA         NA          NA
# 13     NA         NA          NA
# 14     NA         NA          NA
# 15     NA         NA          NA
# 16     NA         NA          NA
# 17     NA         NA          NA
# 18     NA         NA          NA
# 19     NA         NA          NA
# 20     NA         NA          NA
# 21     NA         NA          NA
# 22     NA         NA          NA
# 23     NA         NA          NA
# 24     NA         NA          NA
# 25     NA         NA          NA
# 26     NA         NA          NA
# 27     NA         NA          NA
# 28     NA         NA          NA
# 29     NA         NA          NA
# 30     NA         NA          NA
# ⋮      ⋮          ⋮           ⋮
# 103921 0          979         0
# 103922 0          979         0
# 103923 0          979         0
# 103924 0          979         0
# 103925 0          979         0
# 103926 0          979         0
# 103927 0          979         0
# 103928 0          979         0
# 103929 0          979         0
# 103930 0          979         0
# 103931 0          979         0
# 103932 0          979         0
# 103933 0          979         0
# 103934 0          979         0
# 103935 0          979         0
# 103936 0          979         0
# 103937 0          979         0
# 103938 0          979         0
# 103939 0          979         0
# 103940 0          979         0
# 103941 0          979         0
# 103942 0          979         0
# 103943 0          979         0
# 103944 0          979         0
# 103945 0          979         0
# 103946 0          979         0
# 103947 0          979         0
# 103948 0          979         0
# 103949 0          979         0
# 103950 0          979         0

# %% [raw]
# hrs_endpoints %>% filter(score %in% c("Age+Sex+MedicalHistory", "MedicalHistory")) %>% group_by(endpoint) %>% tally()# %>% arrange(n)

# %%
hrs = hrs_endpoints %>% 
    group_by(endpoint, score, phecode_string, phecode_category) %>% 
    #filter(score %in% c("MedicalHistory", "Age+Sex+MedicalHistory", "Age+Sex+MedicalHistory+I(Age*MH)")) %>%
    #mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    #mutate(phecode_category = factor(phecode_category, levels=pcats_sorted)) %>%
    select(endpoint, score, hrs_mh, hrs_mh_age, hrs_mh_sex, phecode_string, phecode_category) %>%
    ungroup()
hrs
# Out:
#        endpoint     score                            hrs_mh   hrs_mh_age
# 1      OMOP_4306655 Age+Sex+MedicalHistory           4.543129        NA
# 2      OMOP_4306655 Age+Sex+MedicalHistory           4.626850        NA
# 3      OMOP_4306655 Age+Sex+MedicalHistory           4.587563        NA
# 4      OMOP_4306655 Age+Sex+MedicalHistory           4.625650        NA
# 5      OMOP_4306655 Age+Sex+MedicalHistory           4.494688        NA
# 6      OMOP_4306655 Age+Sex+MedicalHistory           4.660579        NA
# 7      OMOP_4306655 Age+Sex+MedicalHistory           4.539814        NA
# 8      OMOP_4306655 Age+Sex+MedicalHistory           4.780453        NA
# 9      OMOP_4306655 Age+Sex+MedicalHistory           4.517744        NA
# 10     OMOP_4306655 Age+Sex+MedicalHistory           4.769463        NA
# 11     OMOP_4306655 Age+Sex+MedicalHistory           4.359181        NA
# 12     OMOP_4306655 Age+Sex+MedicalHistory           4.514668        NA
# 13     OMOP_4306655 Age+Sex+MedicalHistory           4.622716        NA
# 14     OMOP_4306655 Age+Sex+MedicalHistory           4.712837        NA
# 15     OMOP_4306655 Age+Sex+MedicalHistory           4.697196        NA
# 16     OMOP_4306655 Age+Sex+MedicalHistory           4.642005        NA
# 17     OMOP_4306655 Age+Sex+MedicalHistory           4.712686        NA
# 18     OMOP_4306655 Age+Sex+MedicalHistory           4.775385        NA
# 19     OMOP_4306655 Age+Sex+MedicalHistory           4.575772        NA
# 20     OMOP_4306655 Age+Sex+MedicalHistory           4.855588        NA
# 21     OMOP_4306655 Age+Sex+MedicalHistory           4.740240        NA
# 22     OMOP_4306655 Age+Sex+MedicalHistory           4.739648        NA
# 23     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 4.641458 0.9641601
# 24     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 4.467356 0.9711219
# 25     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 4.463099 0.9619386
# 26     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 4.558575 0.9465977
# 27     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 4.570274 0.9347579
# 28     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 4.533612 0.9647811
# 29     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 4.407513 0.9632438
# 30     OMOP_4306655 Age+Sex+MedicalHistory+I(Age*MH) 4.621781 0.9610800
# ⋮      ⋮            ⋮                                ⋮        ⋮
# 103921 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 3.281990 1.032296
# 103922 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 3.453482 1.038220
# 103923 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 3.140458 1.050239
# 103924 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 3.153143 1.026467
# 103925 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 3.293742 1.038996
# 103926 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 3.035455 1.032389
# 103927 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 3.183346 1.023043
# 103928 phecode_979  Age+Sex+MedicalHistory+I(Age*MH) 3.196434 1.035547
# 103929 phecode_979  MedicalHistory                   3.285301       NA
# 103930 phecode_979  MedicalHistory                   3.230414       NA
# 103931 phecode_979  MedicalHistory                   3.854825       NA
# 103932 phecode_979  MedicalHistory                   3.512871       NA
# 103933 phecode_979  MedicalHistory                   3.447379       NA
# 103934 phecode_979  MedicalHistory                   3.054510       NA
# 103935 phecode_979  MedicalHistory                   3.085640       NA
# 103936 phecode_979  MedicalHistory                   3.372215       NA
# 103937 phecode_979  MedicalHistory                   3.115814       NA
# 103938 phecode_979  MedicalHistory                   2.991610       NA
# 103939 phecode_979  MedicalHistory                   3.182099       NA
# 103940 phecode_979  MedicalHistory                   3.322076       NA
# 103941 phecode_979  MedicalHistory                   3.257155       NA
# 103942 phecode_979  MedicalHistory                   3.321948       NA
# 103943 phecode_979  MedicalHistory                   3.144321       NA
# 103944 phecode_979  MedicalHistory                   3.386191       NA
# 103945 phecode_979  MedicalHistory                   3.080827       NA
# 103946 phecode_979  MedicalHistory                   3.104220       NA
# 103947 phecode_979  MedicalHistory                   3.213847       NA
# 103948 phecode_979  MedicalHistory                   2.956662       NA
# 103949 phecode_979  MedicalHistory                   3.125299       NA
# 103950 phecode_979  MedicalHistory                   3.107505       NA
#        hrs_mh_sex phecode_string    phecode_category
# 1            NA   All-Cause Death   Death
# 2            NA   All-Cause Death   Death
# 3            NA   All-Cause Death   Death
# 4            NA   All-Cause Death   Death
# 5            NA   All-Cause Death   Death
# 6            NA   All-Cause Death   Death
# 7            NA   All-Cause Death   Death
# 8            NA   All-Cause Death   Death
# 9            NA   All-Cause Death   Death
# 10           NA   All-Cause Death   Death
# 11           NA   All-Cause Death   Death
# 12           NA   All-Cause Death   Death
# 13           NA   All-Cause Death   Death
# 14           NA   All-Cause Death   Death
# 15           NA   All-Cause Death   Death
# 16           NA   All-Cause Death   Death
# 17           NA   All-Cause Death   Death
# 18           NA   All-Cause Death   Death
# 19           NA   All-Cause Death   Death
# 20           NA   All-Cause Death   Death
# 21           NA   All-Cause Death   Death
# 22           NA   All-Cause Death   Death
# 23           NA   All-Cause Death   Death
# 24     1.096332   All-Cause Death   Death
# 25     1.093205   All-Cause Death   Death
# 26     1.087176   All-Cause Death   Death
# 27     1.042428   All-Cause Death   Death
# 28     1.089448   All-Cause Death   Death
# 29     1.095178   All-Cause Death   Death
# 30     1.105879   All-Cause Death   Death
# ⋮      ⋮          ⋮                 ⋮
# 103921 0.9370709  Transplated organ Stat
# 103922 0.9783811  Transplated organ Stat
# 103923 0.9816744  Transplated organ Stat
# 103924 0.9802424  Transplated organ Stat
# 103925 0.9684674  Transplated organ Stat
# 103926 0.9587607  Transplated organ Stat
# 103927 0.9727791  Transplated organ Stat
# 103928 0.9584598  Transplated organ Stat
# 103929        NA  Transplated organ Stat
# 103930        NA  Transplated organ Stat
# 103931        NA  Transplated organ Stat
# 103932        NA  Transplated organ Stat
# 103933        NA  Transplated organ Stat
# 103934        NA  Transplated organ Stat
# 103935        NA  Transplated organ Stat
# 103936        NA  Transplated organ Stat
# 103937        NA  Transplated organ Stat
# 103938        NA  Transplated organ Stat
# 103939        NA  Transplated organ Stat
# 103940        NA  Transplated organ Stat
# 103941        NA  Transplated organ Stat
# 103942        NA  Transplated organ Stat
# 103943        NA  Transplated organ Stat
# 103944        NA  Transplated organ Stat
# 103945        NA  Transplated organ Stat
# 103946        NA  Transplated organ Stat
# 103947        NA  Transplated organ Stat
# 103948        NA  Transplated organ Stat
# 103949        NA  Transplated organ Stat
# 103950        NA  Transplated organ Stat

# %%
unique(hrs$score)
# Out:
# [1] "Age+Sex+MedicalHistory"           "Age+Sex+MedicalHistory+I(Age*MH)"
# [3] "MedicalHistory"

# %%
purrr::map_dfr(integer(100), ~ hrs %>% group_by(endpoint, score) %>% sample_frac(1, replace=TRUE), .id="i") -> temp_hrs

# %%
library(ggdist)

# %%
temp_hrs_mh = temp_hrs %>% group_by(endpoint, score, phecode_string, phecode_category) %>% median_qi(hrs_mh, hrs_mh_age, hrs_mh_sex, na.rm=TRUE)

# %%
temp_hrs_linear = temp_hrs %>% ungroup() %>%
    filter(score %in% c("MedicalHistory", "Age+Sex+MedicalHistory")) %>%
    group_by(endpoint, score, phecode_string, phecode_category) %>% 
    median_qi(`hrs_mh`, na.rm=TRUE) %>% rename(hr = `hrs_mh`) %>%
    mutate(hr = round(hr, 2), .lower=round(.lower, 2), .upper=round(.upper, 2)) %>%#c(hr, .lower, .upper), round, 1) %>%
    mutate(HR_MedicalHistory = glue("{hr} ({.lower}, {.upper})")) %>% 
    select(endpoint, score, phecode_string, phecode_category, HR_MedicalHistory) %>%
    pivot_wider(names_from="score", values_from="HR_MedicalHistory") %>% 
    select(all_of(c("phecode_category", "endpoint", "phecode_string", "MedicalHistory", 'Age+Sex+MedicalHistory'))) %>% 
    mutate(endpoint = factor(endpoint, levels = endpoint_order)) %>% 
    arrange(endpoint) %>%
    #mutate(endpoint = recode(endpoint, !!!endpoint_map)) %>%
    ungroup()
    
temp_hrs_linear
# Out:
#      phecode_category endpoint
# 1    ID               phecode_001
# 2    ID               phecode_002
# 3    ID               phecode_002-1
# 4    ID               phecode_003
# 5    ID               phecode_004
# 6    ID               phecode_004-1
# 7    ID               phecode_005
# 8    ID               phecode_005-1
# 9    ID               phecode_007
# 10   ID               phecode_007-1
# 11   ID               phecode_008
# 12   ID               phecode_010
# 13   ID               phecode_015
# 14   ID               phecode_015-2
# 15   ID               phecode_019
# 16   ID               phecode_020
# 17   ID               phecode_020-1
# 18   ID               phecode_024
# 19   ID               phecode_030
# 20   ID               phecode_050
# 21   ID               phecode_050-4
# 22   ID               phecode_052
# 23   ID               phecode_052-1
# 24   ID               phecode_052-3
# 25   ID               phecode_052-31
# 26   ID               phecode_052-32
# 27   ID               phecode_052-4
# 28   ID               phecode_054
# 29   ID               phecode_054-2
# 30   ID               phecode_054-3
# ⋮    ⋮                ⋮
# 1546 Signs/Symptoms   phecode_840-9
# 1547 Signs/Symptoms   phecode_841
# 1548 Signs/Symptoms   phecode_841-1
# 1549 Signs/Symptoms   phecode_841-11
# 1550 Signs/Symptoms   phecode_841-12
# 1551 Signs/Symptoms   phecode_841-13
# 1552 Signs/Symptoms   phecode_841-4
# 1553 Signs/Symptoms   phecode_841-5
# 1554 Signs/Symptoms   phecode_848
# 1555 Signs/Symptoms   phecode_848-2
# 1556 Preg             phecode_900-1
# 1557 Preg             phecode_901
# 1558 Preg             phecode_901-3
# 1559 Preg             phecode_940
# 1560 Rx               phecode_969
# 1561 Rx               phecode_973
# 1562 Rx               phecode_974
# 1563 Rx               phecode_977
# 1564 Rx               phecode_977-1
# 1565 Rx               phecode_977-11
# 1566 Rx               phecode_977-4
# 1567 Rx               phecode_977-41
# 1568 Rx               phecode_977-5
# 1569 Rx               phecode_977-51
# 1570 Rx               phecode_977-52
# 1571 Rx               phecode_977-7
# 1572 Rx               phecode_977-71
# 1573 Rx               phecode_977-72
# 1574 Stat             phecode_979
# 1575 Death            OMOP_4306655
#      phecode_string
# 1    Salmonella
# 2    Staphylococcus
# 3    Staphylococcus aureus
# 4    Escherichia coli
# 5    Streptococcus
# 6    Streptococcus pneumoniae
# 7    Mycobacteria
# 8    Mycobacterium tuberculosis
# 9    Hemophilus infection
# 10   Hemophilus influenzae
# 11   Helicobacter [H. pylori]
# 12   Corynebacterium
# 13   Clostridium
# 14   Clostridium difficile
# 15   Treponema
# 16   Borrelia
# 17   Lyme disease
# 18   Pertussis
# 19   Campylobacter
# 20   Enterovirus
# 21   Hand, foot, and mouth disease
# 22   Herpesvirus
# 23   Herpes simplex
# 24   Varicella zoster virus
# 25   Varicella [chickenpox]
# 26   Herpes zoster
# 27   Infectious mononucleosis
# 28   Hepatovirus
# 29   Hepatitis B
# 30   Hepatitis C
# ⋮    ⋮
# 1546 Anaphylactic reaction
# 1547 Drug and medical agent allergy
# 1548 Allergy to other anti-infective agents
# 1549 Penicillin allergy
# 1550 Allergy to antibiotic agent (excluding penicillin)
# 1551 Allergy to sulfonamides
# 1552 Allergy to analgesic agent
# 1553 Allergy to serum and vaccine
# 1554 Nonspecific abnormal findings of other body structures
# 1555 Nonspecific abnormal findings on radiological and other examination of other intrathoracic organs (echo)
# 1556 Spontaneous abortion
# 1557 Abnormal products of conception
# 1558 Missed abortion
# 1559 Malposition and malpresentation of fetus
# 1560 Adverse effects of agents primarily affecting gastrointestinal system
# 1561 Adverse effect of other drug
# 1562 Adverse effect of vaccine
# 1563 Long term (current) drug therapy
# 1564 Long term (current) use of anticoagulants and antithrombotics/antiplatelets
# 1565 Long term (current) use of anticoagulants
# 1566 Long term (current) use of steroids
# 1567 Long term (current) use of inhaled steroids*
# 1568 Long term (current) use of agents affecting hormones
# 1569 Long term (current) use of hormonal contraceptives
# 1570 Hormone replacement therapy (postmenopausal)
# 1571 Long term (current) use of insulin or oral hypoglycemic drugs
# 1572 Long term (current) use of insulin
# 1573 Long term (current) use of oral hypoglycemic drugs
# 1574 Transplated organ
# 1575 All-Cause Death
#      MedicalHistory       Age+Sex+MedicalHistory
# 1    10.85 (8.25, 13.88)  11.51 (8.99, 14.41)
# 2    5.27 (4.41, 6.48)    5.34 (4.46, 6.59)
# 3    5.25 (4.35, 6.59)    5.33 (4.39, 6.72)
# 4    7 (5.76, 8.7)        7.85 (6.58, 9.42)
# 5    2.28 (2.12, 2.44)    2.29 (2.14, 2.45)
# 6    3 (2.65, 3.25)       3 (2.65, 3.26)
# 7    6.57 (5.3, 7.65)     6.63 (5.35, 7.64)
# 8    6.2 (5.1, 7.46)      6.25 (5.09, 7.43)
# 9    3.5 (3.19, 3.95)     3.49 (3.19, 3.94)
# 10   3.52 (3.19, 3.96)    3.49 (3.18, 3.95)
# 11   4.31 (4.02, 5.16)    4.33 (4.14, 5.24)
# 12   5.62 (4.7, 6.46)     9.22 (7.54, 11.1)
# 13   10.59 (8.27, 17.36)  11.2 (8.85, 18.53)
# 14   10.08 (8.45, 18.11)  10.31 (8.67, 18.74)
# 15   5.13 (4.14, 6.19)    5.23 (4.15, 6.25)
# 16   7.87 (6.7, 9.27)     8.07 (6.75, 9.57)
# 17   7.94 (6.7, 9.37)     8.08 (6.75, 9.69)
# 18   10.08 (7.78, 17.09)  10.6 (8.76, 17.66)
# 19   4.84 (4.51, 5.43)    5.02 (4.6, 5.59)
# 20   14.83 (10.08, 37.05) 15.03 (10.71, 36.98)
# 4  phecode_107-2  Malignant neoplasm of the prostate
# 5  phecode_164    Anemia
# 6  phecode_202-2  Type 2 diabetes
# 7  phecode_284    Suicide ideation and attempt or self harm
# 8  phecode_328    Dementias and cerebral degeneration
# 9  phecode_371    Cataract
# 10 phecode_404    Ischemic heart disease
# 11 phecode_424    Heart failure
# 12 phecode_440-11 Deep vein thrombosis [DVT]
# 13 phecode_468    Pneumonia
# 14 phecode_474    Chronic obstructive pulmonary disease [COPD]
# 15 phecode_522-1  Inflammatory bowel disease
# 16 phecode_542-1  Fibrosis and cirrhosis of liver
# 17 phecode_581-1  Pyelonephritis
# 18 phecode_583    Chronic kidney disease
# 19 phecode_705-1  Rheumatoid arthritis
# 20 OMOP_4306655   All-Cause Death
#    MedicalHistory    Age+Sex+MedicalHistory
# 1  4.31 (4.02, 5.16) 4.33 (4.14, 5.24)
# 2  4.17 (3.83, 4.59) 4.05 (3.72, 4.38)
# 3  8.14 (7.4, 8.64)  4.77 (4.31, 5.13)
# 4  4.95 (4.11, 5.87) 2.06 (1.82, 2.29)
# 5  3.98 (3.78, 4.26) 3.9 (3.67, 4.15)
# 6  4.79 (4.66, 5.17) 4.89 (4.73, 5.27)
# 7  3.56 (3.37, 3.71) 3.49 (3.31, 3.64)
# 8  3.46 (3.28, 3.62) 2.42 (2.27, 2.55)
# 9  5.13 (4.93, 5.46) 3.34 (3.25, 3.45)
# 10 3.98 (3.84, 4.14) 3.58 (3.44, 3.78)
# 11 4.56 (4.18, 4.9)  4.12 (3.91, 4.51)
# 12 3.82 (3.62, 4.32) 3.71 (3.5, 4.17)
# 13 2.95 (2.8, 3.28)  2.87 (2.7, 3.15)
# 14 4.35 (4.14, 4.52) 4.22 (4.01, 4.41)
# 15 4.12 (3.79, 4.73) 4.12 (3.79, 4.73)
# 16 4.42 (3.89, 4.88) 4.45 (3.92, 4.93)
# 17 2.98 (2.85, 3.1)  3.09 (2.98, 3.25)
# 18 4.17 (4.01, 4.62) 3.4 (3.3, 3.67)
# 19 3.19 (2.91, 3.56) 3.21 (2.9, 3.56)
# 20 5.14 (4.83, 5.38) 4.63 (4.36, 4.86)

# %% [markdown]
# ## Interactions

# %%
temp_int_age = temp_hrs %>% ungroup() %>%
    filter(score %in% c("Age+Sex+MedicalHistory+I(Age*MH)")) %>%
    pivot_longer(all_of(c("hrs_mh", "hrs_mh_age", "hrs_mh_sex")), names_to="variable", values_to="hr") %>%
    filter(variable == "hrs_mh_age")

# %%
plot_width = 10; plot_height=5; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

ggplot(temp_int_age, aes(x=log(hr))) + geom_density(fill="black", alpha=0.3)
# Out:
# plot without title

# %%
temp_int_sex= temp_hrs %>% ungroup() %>%
    filter(score %in% c("Age+Sex+MedicalHistory+I(Age*MH)")) %>%
    pivot_longer(all_of(c("hrs_mh", "hrs_mh_age", "hrs_mh_sex")), names_to="variable", values_to="hr") %>%
    filter(variable == "hrs_mh_sex")

# %%
plot_width = 10; plot_height=5; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

ggplot(temp_int_sex, aes(x=log(hr))) + geom_density(fill="black", alpha=0.3)
# Out:
# Warning message:
# “Removed 284287 rows containing non-finite values (stat_density).”
# plot without title

# %%
temp_hrs_int = temp_hrs %>% 
    filter(score %in% c("Age+Sex+MedicalHistory+I(Age*MH)")) %>%
    pivot_longer(all_of(c("hrs_mh", "hrs_mh_age", "hrs_mh_sex")), names_to="variable", values_to="hr") %>%
    group_by(endpoint, score, variable, phecode_string, phecode_category) %>% 
    median_qi(hr, na.rm=TRUE) %>% 
    mutate(hr = round(hr, 2), .lower=round(.lower, 2), .upper=round(.upper, 2)) %>%#c(hr, .lower, .upper), round, 1) %>%
    mutate(HR_label = glue("{hr} ({.lower}, {.upper})")) %>% 
    select(endpoint, variable, phecode_string, phecode_category, HR_label) %>%
    pivot_wider(names_from="variable", values_from="HR_label") %>% 
    select(all_of(c("phecode_category", "endpoint", "phecode_string", "hrs_mh", "hrs_mh_age", "hrs_mh_sex"))) %>% 
    mutate(endpoint = factor(endpoint, levels = endpoint_order)) %>% 
    arrange(endpoint) %>%
#mutate(endpoint = recode(endpoint, !!!endpoint_map)) %>%
    ungroup() %>%
    rename(HR_MedHist = hrs_mh, `HR_MedHist*Age`=hrs_mh_age, `HR_MedHist*Sex`=hrs_mh_sex)
    
temp_hrs_int
# Out:
#      phecode_category endpoint
# 1    ID               phecode_001
# 2    ID               phecode_002
# 3    ID               phecode_002-1
# 4    ID               phecode_003
# 5    ID               phecode_004
# 6    ID               phecode_004-1
# 7    ID               phecode_005
# 8    ID               phecode_005-1
# 9    ID               phecode_007
# 10   ID               phecode_007-1
# 11   ID               phecode_008
# 12   ID               phecode_010
# 13   ID               phecode_015
# 14   ID               phecode_015-2
# 15   ID               phecode_019
# 16   ID               phecode_020
# 17   ID               phecode_020-1
# 18   ID               phecode_024
# 19   ID               phecode_030
# 20   ID               phecode_050
# 21   ID               phecode_050-4
# 22   ID               phecode_052
# 23   ID               phecode_052-1
# 24   ID               phecode_052-3
# 25   ID               phecode_052-31
# 26   ID               phecode_052-32
# 27   ID               phecode_052-4
# 28   ID               phecode_054
# 29   ID               phecode_054-2
# 30   ID               phecode_054-3
# ⋮    ⋮                ⋮
# 1546 Signs/Symptoms   phecode_840-9
# 1547 Signs/Symptoms   phecode_841
# 1548 Signs/Symptoms   phecode_841-1
# 1549 Signs/Symptoms   phecode_841-11
# 1550 Signs/Symptoms   phecode_841-12
# 1551 Signs/Symptoms   phecode_841-13
# 1552 Signs/Symptoms   phecode_841-4
# 1553 Signs/Symptoms   phecode_841-5
# 1554 Signs/Symptoms   phecode_848
# 1555 Signs/Symptoms   phecode_848-2
# 1556 Preg             phecode_900-1
# 1557 Preg             phecode_901
# 1558 Preg             phecode_901-3
# 1559 Preg             phecode_940
# 1560 Rx               phecode_969
# 1561 Rx               phecode_973
# 1562 Rx               phecode_974
# 1563 Rx               phecode_977
# 1564 Rx               phecode_977-1
# 1565 Rx               phecode_977-11
# 1566 Rx               phecode_977-4
# 1567 Rx               phecode_977-41
# 1568 Rx               phecode_977-5
# 1569 Rx               phecode_977-51
# 1570 Rx               phecode_977-52
# 1571 Rx               phecode_977-7
# 1572 Rx               phecode_977-71
# 1573 Rx               phecode_977-72
# 1574 Stat             phecode_979
# 1575 Death            OMOP_4306655
#      phecode_string
# 1    Salmonella
# 2    Staphylococcus
# 3    Staphylococcus aureus
# 4    Escherichia coli
# 5    Streptococcus
# 6    Streptococcus pneumoniae
# 7    Mycobacteria
# 8    Mycobacterium tuberculosis
# 9    Hemophilus infection
# 10   Hemophilus influenzae
# 11   Helicobacter [H. pylori]
# 12   Corynebacterium
# 13   Clostridium
# 14   Clostridium difficile
# 15   Treponema
# 16   Borrelia
# 17   Lyme disease
# 18   Pertussis
# 19   Campylobacter
# 20   Enterovirus
# 21   Hand, foot, and mouth disease
# 22   Herpesvirus
# 23   Herpes simplex
# 24   Varicella zoster virus
# 25   Varicella [chickenpox]
# 26   Herpes zoster
# 27   Infectious mononucleosis
# 28   Hepatovirus
# 29   Hepatitis B
# 30   Hepatitis C
# ⋮    ⋮
# 1546 Anaphylactic reaction
# 1547 Drug and medical agent allergy
# 1548 Allergy to other anti-infective agents
# 1549 Penicillin allergy
# 1550 Allergy to antibiotic agent (excluding penicillin)
# 1551 Allergy to sulfonamides
# 1552 Allergy to analgesic agent
# 1553 Allergy to serum and vaccine
# 1554 Nonspecific abnormal findings of other body structures
# 1555 Nonspecific abnormal findings on radiological and other examination of other intrathoracic organs (echo)
# 1556 Spontaneous abortion
# 1557 Abnormal products of conception
# 1558 Missed abortion
# 1559 Malposition and malpresentation of fetus
# 1560 Adverse effects of agents primarily affecting gastrointestinal system
# 1561 Adverse effect of other drug
# 1562 Adverse effect of vaccine
# 1563 Long term (current) drug therapy
# 1564 Long term (current) use of anticoagulants and antithrombotics/antiplatelets
# 1565 Long term (current) use of anticoagulants
# 1566 Long term (current) use of steroids
# 1567 Long term (current) use of inhaled steroids*
# 1568 Long term (current) use of agents affecting hormones
# 1569 Long term (current) use of hormonal contraceptives
# 1570 Hormone replacement therapy (postmenopausal)
# 1571 Long term (current) use of insulin or oral hypoglycemic drugs
# 1572 Long term (current) use of insulin
# 1573 Long term (current) use of oral hypoglycemic drugs
# 1574 Transplated organ
# 1575 All-Cause Death
#      HR_MedHist           HR_MedHist*Age    HR_MedHist*Sex
# 1    10.26 (8.13, 14.73)  1.19 (1.09, 1.35) 1.42 (1.17, 2.07)
# 2    5.35 (4.38, 6.61)    1.05 (1.02, 1.11) 0.98 (0.91, 1.04)
# 3    5.54 (4.3, 6.72)     1.05 (1.02, 1.1)  0.98 (0.91, 1.03)
# 4    7.44 (6.08, 8.84)    0.89 (0.83, 0.94) 1.23 (1.03, 1.42)
# 5    2.28 (2.1, 2.42)     0.97 (0.95, 0.98) 1.04 (1.01, 1.09)
# 6    3.1 (2.63, 3.43)     0.96 (0.95, 3.38) 0.93 (0.75, 1.38)
# 7    6.82 (5.23, 7.71)    1.04 (0.97, 1.11) 1 (0.88, 1.18)
# 1554 4.12 (3.9, 4.3)      0.96 (0.95, 0.97) 1.05 (1.02, 1.09)
# 1555 4.59 (4.36, 4.89)    0.94 (0.94, 0.97) 0.93 (0.89, 0.95)
# 1556 1.89 (1.55, 3.38)    0.51 (0.46, 0.68) NA (NA, NA)
# 1557 13.77 (7.05, 22.18)  0.88 (0.76, 0.99) NA (NA, NA)
# 1558 17.07 (8.52, 25.89)  0.84 (0.73, 0.94) NA (NA, NA)
# 1559 7.62 (6.33, 8.93)    1.19 (1.02, 1.34) NA (NA, NA)
# 1560 3.53 (3.35, 3.71)    0.98 (0.97, 1)    1.05 (1.02, 1.08)
# 1561 5.81 (5.16, 6.49)    0.95 (0.88, 0.99) 0.99 (0.93, 1.08)
# 1562 7.24 (5.33, 8.96)    0.88 (0.82, 1)    1.02 (0.84, 1.21)
# 1563 5.92 (5.65, 6.22)    1.04 (1.02, 1.06) 1.07 (0.99, 1.11)
# 1564 5.43 (4.95, 7.12)    0.98 (0.94, 1)    0.91 (0.83, 0.98)
# 1565 5.45 (4.98, 7.1)     0.98 (0.94, 1)    0.9 (0.83, 0.98)
# 1566 4.99 (4.71, 22.1)    0.99 (0.97, 3.45) 1.08 (0.14, 1.14)
# 1567 5.06 (4.71, 22.77)   0.99 (0.97, 3.75) 1.08 (0.35, 1.84)
# 1568 4.92 (0.3, 6.22)     1.01 (0.04, 1.1)  0.59 (0.15, 657.96)
# 1569 1.07 (0.28, 10.04)   0.06 (0, 1.24)    NA (NA, NA)
# 1570 8.6 (7.77, 10.56)    1.44 (1.35, 1.56) NA (NA, NA)
# 1571 4.66 (4.49, 4.82)    0.99 (0.98, 0.99) 0.95 (0.92, 0.99)
# 1572 4.42 (4.27, 4.65)    1.04 (1.02, 1.05) 0.95 (0.93, 0.98)
# 1573 4.54 (1.75, 4.83)    0.99 (0.98, 5.83) 0.96 (0.93, 10.87)
# 1574 3.27 (3.04, 3.85)    1.03 (1, 1.05)    0.97 (0.94, 1.01)
# 1575 4.49 (4.22, 4.66)    0.96 (0.93, 0.98) 1.1 (1.04, 1.17)

# %%
temp_hrs_int %>% filter(endpoint %in% endpoint_selection) %>% select(-phecode_category) %>%
# Out:
#    endpoint       phecode_string
# 1  phecode_008    Helicobacter [H. pylori]
# 2  phecode_092-2  Sepsis
# 3  phecode_105    Malignant neoplasm of the breast
# 4  phecode_107-2  Malignant neoplasm of the prostate
# 5  phecode_164    Anemia
# 6  phecode_202-2  Type 2 diabetes
# 7  phecode_284    Suicide ideation and attempt or self harm
# 8  phecode_328    Dementias and cerebral degeneration
# 9  phecode_371    Cataract
# 10 phecode_404    Ischemic heart disease
# 11 phecode_424    Heart failure
# 12 phecode_440-11 Deep vein thrombosis [DVT]
# 13 phecode_468    Pneumonia
# 14 phecode_474    Chronic obstructive pulmonary disease [COPD]
# 15 phecode_522-1  Inflammatory bowel disease
# 16 phecode_542-1  Fibrosis and cirrhosis of liver
# 17 phecode_581-1  Pyelonephritis
# 18 phecode_583    Chronic kidney disease
# 19 phecode_705-1  Rheumatoid arthritis
# 20 OMOP_4306655   All-Cause Death
#    HR_MedHist        HR_MedHist*Age    HR_MedHist*Sex
# 1  4.29 (3.94, 4.96) 0.99 (0.97, 1.01) 1.1 (1.06, 1.16)
# 2  4.05 (3.72, 4.4)  1 (0.98, 1.02)    1.02 (0.98, 1.1)
# 3  4.92 (4.42, 5.28) 0.95 (0.93, 0.98) 0.48 (0.36, 0.66)
# 4  3.21 (2.7, 3.74)  0.54 (0.5, 0.58)  NA (NA, NA)
# 5  3.93 (3.76, 4.21) 1 (0.98, 1.02)    0.97 (0.94, 1.03)
# 6  4.93 (4.76, 5.36) 0.9 (0.89, 0.93)  0.99 (0.94, 1.06)
# 7  3.42 (1.24, 3.74) 1.04 (0.08, 1.06) 1 (0.96, 1.65)
# 8  2.71 (2.61, 2.85) 0.86 (0.84, 0.89) 1.03 (1, 1.07)
# 9  3.37 (3.27, 3.51) 0.92 (0.91, 0.94) 1.1 (1.07, 1.12)
# 10 4.1 (3.7, 4.31)   0.87 (0.86, 0.88) 0.86 (0.83, 0.88)
# 11 4.51 (4.11, 4.82) 0.94 (0.92, 0.95) 0.92 (0.89, 0.96)
# 12 3.73 (3.56, 4.08) 0.95 (0.93, 0.99) 1.02 (0.95, 1.07)
# 13 2.9 (2.74, 3.15)  0.99 (0.98, 1)    1 (0.99, 1.03)
# 14 4.26 (4.02, 4.45) 0.93 (0.91, 0.94) 1.03 (0.98, 1.08)
# 15 4.03 (3.69, 4.74) 0.93 (0.9, 0.97)  1.07 (1, 1.12)
# 16 4.55 (0.78, 5.11) 1 (0.72, 1.03)    0.93 (0.86, 9.29)
# 17 3.02 (2.91, 3.22) 0.94 (0.92, 0.97) 1.06 (1, 1.12)
# 18 3.42 (3.31, 3.73) 0.93 (0.91, 0.95) 1.06 (1.05, 1.11)
# 19 3.13 (2.81, 3.51) 0.92 (0.91, 0.95) 1.07 (1.05, 1.13)
# 20 4.49 (4.22, 4.66) 0.96 (0.93, 0.98) 1.1 (1.04, 1.17)

# %%
temp_hrs_int %>% arrange(`HR_MedHist*Age`)
# Out:
#      phecode_category endpoint
# 1    Rx               phecode_977-51
# 2    Mental           phecode_286-3
# 3    Preg             phecode_900-1
# 4    Neoplasms        phecode_107-2
# 5    Neoplasms        phecode_107
# 6    Genitourinary    phecode_600
# 7    Genitourinary    phecode_609
# 8    Musc/Skel        phecode_712-1
# 9    Genitourinary    phecode_619-2
# 10   Signs/Symptoms   phecode_822
# 11   Signs/Symptoms   phecode_822-8
# 12   Genitourinary    phecode_602-4
# 13   Genitourinary    phecode_602
# 14   Genitourinary    phecode_618-2
# 15   Genitourinary    phecode_610-5
# 16   ID               phecode_052-4
# 17   GI               phecode_500-4
# 18   GI               phecode_500
# 19   Neuro            phecode_328-7
# 20   Eye              phecode_376-1
# 21   Genitourinary    phecode_618
# 22   Eye              phecode_374-52
# 23   Eye              phecode_376
# 24   Eye              phecode_376-2
# 25   Genitourinary    phecode_618-1
# 26   Genitourinary    phecode_596-1
# 27   GI               phecode_506-6
# 28   Musc/Skel        phecode_709-1
# 29   Genitourinary    phecode_629
# 30   Musc/Skel        phecode_709-11
# ⋮    ⋮                ⋮
# 1546 Neuro            phecode_334-44
# 1547 Eye              phecode_361-9
# 1548 Metab            phecode_249
# 1549 Metab            phecode_252
# 1550 Endo             phecode_214
# 1551 Cardio           phecode_433-32
# 1552 Neoplasms        phecode_109-1
# 1553 GI               phecode_522-91
# 1554 Genitourinary    phecode_620
# 1555 Endo             phecode_214-11
# 1556 Genitourinary    phecode_626-11
# 1557 ID               phecode_084-4
# 1558 Endo             phecode_203
# 1559 Genitourinary    phecode_625-1
# 1560 Eye              phecode_381-11
# 1561 Genitourinary    phecode_625-2
# 1562 Derm             phecode_684-14
# 1563 Resp             phecode_472-4
# 1564 Genitourinary    phecode_627-1
# 1565 Genitourinary    phecode_626-2
# 1566 Genitourinary    phecode_619-1
# 1567 Genitourinary    phecode_627-2
# 1568 Neoplasms        phecode_144-12
# 1569 Genitourinary    phecode_626-1
# 1570 Genitourinary    phecode_626-14
# 1571 Rx               phecode_977-52
# 1572 Neuro            phecode_338
# 1573 Neuro            phecode_338-1
# 1574 Genitourinary    phecode_627-4
# 1575 Genitourinary    phecode_626-13
#      phecode_string
# 1    Long term (current) use of hormonal contraceptives
# 2    Premenstrual dysphoric disorder
# 3    Spontaneous abortion
# 4    Malignant neoplasm of the prostate
# 5    Malignant neoplasm of male genitalia
# 6    Benign prostatic hyperplasia
# 7    Male infertility
# 8    Loose body in joint
# 9    Disorders of uterus, NEC
# 10   Other and nonspecific abnormal cytological, histological and immunological findings
# 11   Abnormal tumor markers
# 12   Elevated prostate specific antigen [PSA]
# 13   Other disorders of prostate
# 14   Uterine/Uterovaginal prolapse
# 15   Mammary duct ectasia
# 16   Infectious mononucleosis
# 17   Disturbances in tooth eruption
# 18   Disorders of tooth develoment
# 19   Vascular dementia
# 20   Vitreous degeneration
# 21   Genital prolapse
# 22   Macular cyst, hole, or pseudohole
# 23   Disorders of vitreous body
# 24   Vitreous opacities
# 25   Prolapse of vaginal walls
# 26   Bladder neck obstruction
# 27   Mucocele of salivary gland
# 28   Acquired deformities of fingers
# 29   Female infertility
# 30   Mallet finger
# ⋮    ⋮
# 1546 Sixth [abducent] nerve palsy
# 1547 Ectropion of eyelid
# 1548 Amyloidosis
# 1549 Other and unspecified disorders of metabolism
# 1550 Ovarian dysfunction
# 1551 Vertebro-basilar artery syndrome
# 1552 Malignant neoplasm of eye
# 1553 Atrophic gastritis
# 1554 Dysplasia of female genital organs
# 1555 Premature menopause
# 1556 Absent or infrequent menstruation
# 1557 Trichomoniasis
# 1558 Metabolic syndrome [Dysmetabolic syndrome X]
# 1559 Dyspareunia
# 1560 Ophthalmoplegia
# 1561 Postcoital bleeding
# 1562 Androgenic alopecia*
# 1563 Laryngeal spasm
# 1564 Postmenopausal bleeding
# 1565 Dysmenorrhea
# 1566 Noninflammatory disorders of ovary, fallopian tube, and broad ligament
# 1567 Symptomatic menopause
    write_csv("outputs/SupplTable2_HRsAll.csv")

# %%
select(all_of(c("phecode_category", "endpoint", "phecode_string", "MedicalHistory", 'Age+Sex+MedicalHistory'))) %>% 
    mutate(endpoint = factor(endpoint, levels = endpoint_order)) %>% 
    arrange(phecode_category, endpoint) %>%
%>% filter(endpoint %in% endpoint_selection)

# %%
temp_hrs_agg

# %%
temp_hrs_agg = temp_hrs %>% filter(endpoint %in% ep_sel) %>%
    group_by(endpoint, features) %>% median_qi(`exp(coef)`, na.rm=TRUE) %>% rename(hr = `exp(coef)`) %>%
    mutate(hr = round(hr, 2), .lower=round(.lower, 2), .upper=round(.upper, 2)) %>%#c(hr, .lower, .upper), round, 1) %>%
    mutate(HR_Metabolomics = glue("{hr} ({.lower}, {.upper})")) %>% 
    select(endpoint, features, HR_Metabolomics) %>%
    pivot_wider(names_from="features", values_from="HR_Metabolomics") %>% 
    select(all_of(c("endpoint", 'Age+Sex+Metabolomics', 
                    #'SCORE2+Metabolomics', 
                    'ASCVD+Metabolomics', 
                   "PANEL+Metabolomics"))) %>% 
    mutate(endpoint = factor(endpoint, levels = endpoint_order)) %>% arrange(endpoint) %>%
    mutate(endpoint = recode(endpoint, !!!endpoint_map)) %>%
    ungroup()
temp_hrs_agg
# Out:
#    endpoint            Age+Sex+Metabolomics ASCVD+Metabolomics
# 1  MACE                1.63 (1.6, 1.65)     1.46 (1.43, 1.49)
# 2  CHD                 1.59 (1.58, 1.65)    1.44 (1.43, 1.48)
# 3  Cerebral Stroke     1.72 (1.68, 1.76)    1.58 (1.54, 1.61)
# 4  Dementia            1.56 (1.54, 1.72)    1.5 (1.48, 1.67)
# 5  Heart Failure       1.8 (1.78, 1.87)     1.68 (1.65, 1.73)
# 6  Atrial Fibrillation 1.48 (1.46, 1.53)    1.39 (1.37, 1.43)
# 7  T2 Diabetes         3.83 (3.71, 4.01)    3.75 (3.64, 4.04)
# 8  Liver Disease       1.72 (1.7, 1.81)     1.66 (1.64, 1.74)
# 9  Renal Disease       1.71 (1.67, 1.74)    1.62 (1.6, 1.65)
# 10 PAD                 1.58 (1.55, 1.7)     1.5 (1.47, 1.59)
# 11 Ven. Thrombosis     1.66 (1.56, 1.8)     1.65 (1.56, 1.79)
# 12 AAA                 1.85 (1.8, 1.89)     1.82 (1.77, 1.9)
# 13 COPD                1.56 (1.55, 1.63)    1.45 (1.44, 1.51)
# 14 Asthma              1.52 (1.45, 2.29)    1.48 (1.42, 2.21)
# 15 Cataracts           1.21 (1.2, 1.24)     1.13 (1.12, 1.16)
# 16 Fractures           1.29 (1.28, 1.68)    1.29 (1.27, 1.61)
# 17 Lung Cancer         2.08 (2.01, 2.17)    1.73 (1.68, 1.77)
# 18 Prostate Cancer     0.96 (0.94, 0.97)    0.98 (0.96, 0.99)
#    PANEL+Metabolomics
# 1  1.37 (1.35, 1.4)
# 2  1.32 (1.3, 1.33)
# 3  1.55 (1.51, 1.59)
# 4  1.46 (1.43, 1.58)
# 5  1.43 (1.41, 1.47)
# 6  1.24 (1.21, 1.25)
# 7  2.5 (2.34, 2.67)
# 8  1.44 (1.4, 1.47)
# 9  1.34 (1.32, 1.36)
# 10 1.41 (1.38, 1.48)
# 11 1.49 (1.42, 1.58)
# 12 1.89 (1.82, 1.97)
# 13 1.33 (1.32, 1.37)
# 14 1.35 (1.27, 1.77)
# 15 1.07 (1.05, 1.08)
# 16 1.23 (1.22, 1.42)
# 17 1.56 (1.53, 1.61)
# 18 0.99 (0.98, 1.01)

# %% [raw]
# temp_hrs_agg %>% gt(rowname_col="endpoint") %>%
#     tab_stubhead(label = "Endpoint") %>%
#     tab_header(
#         title = "Metabolomic Hazard Ratio adjusted for Clinical Predictors"
#     ) %>%
#   cols_label(
#     `Age+Sex+Metabolomics` = md("adj. for Age+Sex"),
#    # `SCORE2+Metabolomics` = md("adj. for SCORE2"),
#     `ASCVD+Metabolomics` = md("adj. for ASCVD"),
#       `PANEL+Metabolomics` = md("adj. for PANEL")
#   ) %>%
#  #tab_style(
#  #   style = list(
#  #     cell_text(weight = "bold")
#  #     ),
#  #   locations = cells_stub()
#  # ) %>%
# gtsave("SupplTable3_hrs.html")

# %%
fts_map = c(
    "Metabolomics" = "MET",
    "COX_Age+Sex" = "AgeSex",
    "Age+Sex+Metabolomics" = "AgeSex+MET",
    "COX_ASCVD" = "ASCVD",
    "ASCVD+Metabolomics" = "ASCVD+MET",
    "COX_PANEL" = "PANEL", 
    "PANEL+Metabolomics" = "PANEL+MET"
               )

# %%
hr_labels = temp_hrs_agg %>% 
    pivot_longer(-endpoint, names_to="features", values_to="HR")
hr_labels
# Out:
#    endpoint            features             HR
# 1  MACE                Age+Sex+Metabolomics 1.63 (1.6, 1.65)
# 2  MACE                ASCVD+Metabolomics   1.46 (1.43, 1.49)
# 3  MACE                PANEL+Metabolomics   1.37 (1.35, 1.4)
# 4  CHD                 Age+Sex+Metabolomics 1.59 (1.58, 1.65)
# 5  CHD                 ASCVD+Metabolomics   1.44 (1.43, 1.48)
# 6  CHD                 PANEL+Metabolomics   1.32 (1.3, 1.33)
# 7  Cerebral Stroke     Age+Sex+Metabolomics 1.72 (1.68, 1.76)
# 8  Cerebral Stroke     ASCVD+Metabolomics   1.58 (1.54, 1.61)
# 9  Cerebral Stroke     PANEL+Metabolomics   1.55 (1.51, 1.59)
# 10 Dementia            Age+Sex+Metabolomics 1.56 (1.54, 1.72)
# 11 Dementia            ASCVD+Metabolomics   1.5 (1.48, 1.67)
# 12 Dementia            PANEL+Metabolomics   1.46 (1.43, 1.58)
# 13 Heart Failure       Age+Sex+Metabolomics 1.8 (1.78, 1.87)
# 14 Heart Failure       ASCVD+Metabolomics   1.68 (1.65, 1.73)
# 15 Heart Failure       PANEL+Metabolomics   1.43 (1.41, 1.47)
# 16 Atrial Fibrillation Age+Sex+Metabolomics 1.48 (1.46, 1.53)
# 17 Atrial Fibrillation ASCVD+Metabolomics   1.39 (1.37, 1.43)
# 18 Atrial Fibrillation PANEL+Metabolomics   1.24 (1.21, 1.25)
# 19 T2 Diabetes         Age+Sex+Metabolomics 3.83 (3.71, 4.01)
# 20 T2 Diabetes         ASCVD+Metabolomics   3.75 (3.64, 4.04)
# 21 T2 Diabetes         PANEL+Metabolomics   2.5 (2.34, 2.67)
# 22 Liver Disease       Age+Sex+Metabolomics 1.72 (1.7, 1.81)
# 23 Liver Disease       ASCVD+Metabolomics   1.66 (1.64, 1.74)
# 24 Liver Disease       PANEL+Metabolomics   1.44 (1.4, 1.47)
# 25 Renal Disease       Age+Sex+Metabolomics 1.71 (1.67, 1.74)
# 26 Renal Disease       ASCVD+Metabolomics   1.62 (1.6, 1.65)
# 27 Renal Disease       PANEL+Metabolomics   1.34 (1.32, 1.36)
# 28 PAD                 Age+Sex+Metabolomics 1.58 (1.55, 1.7)
# 29 PAD                 ASCVD+Metabolomics   1.5 (1.47, 1.59)
# 30 PAD                 PANEL+Metabolomics   1.41 (1.38, 1.48)
# 31 Ven. Thrombosis     Age+Sex+Metabolomics 1.66 (1.56, 1.8)
# 32 Ven. Thrombosis     ASCVD+Metabolomics   1.65 (1.56, 1.79)
# 33 Ven. Thrombosis     PANEL+Metabolomics   1.49 (1.42, 1.58)
# 34 AAA                 Age+Sex+Metabolomics 1.85 (1.8, 1.89)
# 35 AAA                 ASCVD+Metabolomics   1.82 (1.77, 1.9)
# 36 AAA                 PANEL+Metabolomics   1.89 (1.82, 1.97)
# 37 COPD                Age+Sex+Metabolomics 1.56 (1.55, 1.63)
# 38 COPD                ASCVD+Metabolomics   1.45 (1.44, 1.51)
# 39 COPD                PANEL+Metabolomics   1.33 (1.32, 1.37)
# 40 Asthma              Age+Sex+Metabolomics 1.52 (1.45, 2.29)
# 41 Asthma              ASCVD+Metabolomics   1.48 (1.42, 2.21)
# 42 Asthma              PANEL+Metabolomics   1.35 (1.27, 1.77)
# 43 Cataracts           Age+Sex+Metabolomics 1.21 (1.2, 1.24)
# 44 Cataracts           ASCVD+Metabolomics   1.13 (1.12, 1.16)
# 45 Cataracts           PANEL+Metabolomics   1.07 (1.05, 1.08)
# 46 Fractures           Age+Sex+Metabolomics 1.29 (1.28, 1.68)
# 47 Fractures           ASCVD+Metabolomics   1.29 (1.27, 1.61)
# 48 Fractures           PANEL+Metabolomics   1.23 (1.22, 1.42)
# 49 Lung Cancer         Age+Sex+Metabolomics 2.08 (2.01, 2.17)
# 50 Lung Cancer         ASCVD+Metabolomics   1.73 (1.68, 1.77)
# 51 Lung Cancer         PANEL+Metabolomics   1.56 (1.53, 1.61)
# 52 Prostate Cancer     Age+Sex+Metabolomics 0.96 (0.94, 0.97)
# 53 Prostate Cancer     ASCVD+Metabolomics   0.98 (0.96, 0.99)
# 54 Prostate Cancer     PANEL+Metabolomics   0.99 (0.98, 1.01)

# %%
temp_hr
# Out:
#      endpoint       score
# 1    OMOP_4306655   Age+Sex+MedicalHistory
# 2    phecode_001    Age+Sex+MedicalHistory
# 3    phecode_002    Age+Sex+MedicalHistory
# 4    phecode_002-1  Age+Sex+MedicalHistory
# 5    phecode_003    Age+Sex+MedicalHistory
# 6    phecode_004    Age+Sex+MedicalHistory
# 7    phecode_004-1  Age+Sex+MedicalHistory
# 8    phecode_005    Age+Sex+MedicalHistory
# 9    phecode_005-1  Age+Sex+MedicalHistory
# 10   phecode_006    Age+Sex+MedicalHistory
# 11   phecode_006-2  Age+Sex+MedicalHistory
# 12   phecode_007    Age+Sex+MedicalHistory
# 13   phecode_007-1  Age+Sex+MedicalHistory
# 14   phecode_009    Age+Sex+MedicalHistory
# 15   phecode_010    Age+Sex+MedicalHistory
# 16   phecode_015    Age+Sex+MedicalHistory
# 17   phecode_016    Age+Sex+MedicalHistory
# 18   phecode_016-1  Age+Sex+MedicalHistory
# 19   phecode_019    Age+Sex+MedicalHistory
# 20   phecode_023    Age+Sex+MedicalHistory
# 21   phecode_027    Age+Sex+MedicalHistory
# 22   phecode_030    Age+Sex+MedicalHistory
# 23   phecode_033    Age+Sex+MedicalHistory
# 24   phecode_050    Age+Sex+MedicalHistory
# 25   phecode_050-5  Age+Sex+MedicalHistory
# 26   phecode_052    Age+Sex+MedicalHistory
# 27   phecode_052-1  Age+Sex+MedicalHistory
# 28   phecode_052-3  Age+Sex+MedicalHistory
# 29   phecode_052-31 Age+Sex+MedicalHistory
# 30   phecode_052-32 Age+Sex+MedicalHistory
# ⋮    ⋮              ⋮
# 972  phecode_904    Age+Sex+MedicalHistory
# 973  phecode_908    Age+Sex+MedicalHistory
# 974  phecode_908-1  Age+Sex+MedicalHistory
# 975  phecode_908-2  Age+Sex+MedicalHistory
# 976  phecode_909    Age+Sex+MedicalHistory
# 977  phecode_909-2  Age+Sex+MedicalHistory
# 978  phecode_911    Age+Sex+MedicalHistory
# 979  phecode_912    Age+Sex+MedicalHistory
# 980  phecode_912-1  Age+Sex+MedicalHistory
# 981  phecode_912-2  Age+Sex+MedicalHistory
# 982  phecode_916    Age+Sex+MedicalHistory
# 983  phecode_916-1  Age+Sex+MedicalHistory
# 984  phecode_926    Age+Sex+MedicalHistory
# 985  phecode_926-1  Age+Sex+MedicalHistory
# 986  phecode_926-11 Age+Sex+MedicalHistory
# 987  phecode_930    Age+Sex+MedicalHistory
# 988  phecode_938    Age+Sex+MedicalHistory
# 989  phecode_945    Age+Sex+MedicalHistory
# 990  phecode_945-3  Age+Sex+MedicalHistory
# 991  phecode_949    Age+Sex+MedicalHistory
# 992  phecode_950    Age+Sex+MedicalHistory
# 993  phecode_954    Age+Sex+MedicalHistory
# 994  phecode_976    Age+Sex+MedicalHistory
# 995  phecode_979    Age+Sex+MedicalHistory
# 996  phecode_979-2  Age+Sex+MedicalHistory
# 997  phecode_981    Age+Sex+MedicalHistory
# 998  phecode_983    Age+Sex+MedicalHistory
# 999  phecode_988    Age+Sex+MedicalHistory
# 1000 phecode_989    Age+Sex+MedicalHistory
# 1001 phecode_997    Age+Sex+MedicalHistory
#      phecode_string
# 1    All-Cause Death
# 2    Salmonella
# 3    Staphylococcus
# 4    Staphylococcus aureus
# 5    Escherichia coli
# 6    Streptococcus
# 7    Streptococcus pneumoniae
# 8    Mycobacteria
# 9    Mycobacterium tuberculosis
# 10   Neisseria
# 11   Neisseria gonorrhea
# 12   Hemophilus infection
# 13   Hemophilus influenzae
# 14   Pseudomonas
# 15   Corynebacterium
# 16   Clostridium
# 17   Chlamydia
# 18   Chlamydia trachomatis
# 19   Treponema
# 20   Vibrio
# 21   Shigella
# 22   Campylobacter
# 23   Francisella
# 24   Enterovirus
# 25   Enteroviral vesicular pharyngitis
# 26   Herpesvirus
# 27   Herpes simplex
# 28   Varicella zoster virus
# 29   Varicella [chickenpox]
# 30   Herpes zoster
# ⋮    ⋮
# 972  Bleeding in pregnancy
# 973  Edema, proteinuria and hypertensive disorders in pregnancy, childbirth and the puerperium
# 974  Preeclampsia and eclampsia
# 975  Pre-existing hypertension complicating pregnancy, childbirth and the puerperium
# 976  Diabetes mellitus or abnormal glucose in pregnancy, childbirth, and the puerperium
# 977  Pre-existing diabetes mellitus in pregnancy*
# 978  Excessive vomiting in pregnancy
# 979  Venous complications in pregnancy
# 980  Varicose veins in pregnancy
# 981  Thrombotic conditions of pregnancy
# 982  Infections and carrier state in pregnancy
# 983  Infections of genitourinary tract in pregnancy
# 984  Mental disorders complicating pregnancy, childbirth and the puerperium
# 985  Postpartum mood disturbance*
# 986  Postpartum depression*
# 987  Maternal care for abnormality of pelvic organs
# 988  Other conditions or status of the mother complicating pregnancy, childbirth, or the puerperium
# 989  Rupture of uterus
# 990  Postpartum hemorrhage
# 991  Complications of labor and delivery NEC
# 992  Puerperal infection or fever
# 993  Other disorders of the breast associated with childbirth and disorders of lactation
# 994  Adverse effect of anesthesia
# 995  Transplated organ
# 996  Kidney transplant
# 997  Family history of malignant neoplasm
# 998  Family history of other endocrine and metabolic diseases
# 999  Family history of cardiovascular disease
# 1000 Family history of respiratory disease
# 1001 Family history of other condition
#      phecode_category hr
# 1    Death             2.207289
# 2    ID                8.157043
# 3    ID                1.986996
# 4    ID                2.159156
# 5    ID                1.941919
# 6    ID                3.087620
# 7    ID                2.944650
# 8    ID                7.613046
# 9    ID                7.847273
# 10   ID                8.120005
# 11   ID                8.476068
# 12   ID                3.463542
# 13   ID                3.257722
# 14   ID                2.588190
# 15   ID                7.839101
# 16   ID                2.317005
# 17   ID                8.137816
# 18   ID                8.046239
# 19   ID               10.127524
# 20   ID               12.568925
# 21   ID               11.729271
# 22   ID                2.897553
# 23   ID                7.706797
# 24   ID                8.306959
# 25   ID                9.403907
# 26   ID                4.885795
# 27   ID                6.320863
# 28   ID                4.506290
# 29   ID                4.054262
# 30   ID                4.549147
# ⋮    ⋮                ⋮
# 972  Preg              2.005769
# 973  Preg              9.424524
# 974  Preg              8.865542
# 975  Preg              8.904547
# 976  Preg              9.200846
# 977  Preg             10.404671
# 978  Preg              9.496919
# 979  Preg             13.552180
# 980  Preg             13.357041
# 981  Preg             11.547513
# 982  Preg              5.540533
# 983  Preg              5.561964
# 984  Preg             11.828472
# 985  Preg             12.541025
# 986  Preg             12.539458
# 987  Preg             10.318040
# 988  Preg              7.635932
# 989  Preg              3.264311
# 990  Preg              3.243882
# 991  Preg              7.550151
# 992  Preg              5.665712
# 993  Preg              9.120012
# 994  Rx                6.949716
# 995  Stat              2.797251
# 996  Stat              2.788227
# 997  Stat              1.673190
# 998  Stat              4.611321
# 999  Stat              2.429131
# 1000 Stat              4.798277
# 1001 Stat              1.896414

# %%
endpoints_sorted = (temp_hr %>% filter(score == "Age+Sex+MedicalHistory") %>% arrange(endpoint))$endpoint

# %%
pcats_sorted = (temp_hr %>% arrange(endpoint) %>% distinct(phecode_category))$phecode_category

# %%
temp_hr %>% arrange(desc(hr)) %>% filter(endpoint %in% endpoint_selection)
# Out:
#    endpoint       score
# 1  phecode_287-5  Age+Sex+MedicalHistory
# 2  phecode_908-1  Age+Sex+MedicalHistory
# 3  phecode_440-11 Age+Sex+MedicalHistory
# 4  phecode_976    Age+Sex+MedicalHistory
# 5  phecode_123    Age+Sex+MedicalHistory
# 6  phecode_424    Age+Sex+MedicalHistory
# 7  phecode_542-1  Age+Sex+MedicalHistory
# 8  phecode_583    Age+Sex+MedicalHistory
# 9  phecode_474    Age+Sex+MedicalHistory
# 10 phecode_284    Age+Sex+MedicalHistory
# 11 phecode_705-1  Age+Sex+MedicalHistory
# 12 phecode_328    Age+Sex+MedicalHistory
# 13 phecode_232    Age+Sex+MedicalHistory
# 14 phecode_404    Age+Sex+MedicalHistory
# 15 phecode_092-2  Age+Sex+MedicalHistory
# 16 phecode_468    Age+Sex+MedicalHistory
# 17 phecode_164    Age+Sex+MedicalHistory
# 18 phecode_200-1  Age+Sex+MedicalHistory
# 19 phecode_518    Age+Sex+MedicalHistory
# 20 phecode_105    Age+Sex+MedicalHistory
#    phecode_string                                       phecode_category
# 1  Drug-induced psychotic disorder                      Mental
# 2  Preeclampsia and eclampsia                           Preg
# 3  Deep vein thrombosis [DVT]                           Cardio
# 4  Adverse effect of anesthesia                         Rx
# 5  Multiple myeloma and malignant plasma cell neoplasms Neoplasms
# 6  Heart failure                                        Cardio
# 7  Fibrosis and cirrhosis of liver                      GI
# 8  Chronic kidney disease                               Genitourinary
# 9  Chronic obstructive pulmonary disease [COPD]         Resp
# 10 Suicide ideation and attempt or self harm            Mental
# 11 Rheumatoid arthritis                                 Musc/Skel
# 12 Dementias and cerebral degeneration                  Neuro
# 13 Vitamin deficiencies                                 Metab
# 14 Ischemic heart disease                               Cardio
# 15 Sepsis                                               ID
# 16 Pneumonia                                            Resp
# 17 Anemia                                               Blood
# 18 Hypothyroidism                                       Endo
# 19 Appendicitis                                         GI
# 20 Malignant neoplasm of the breast                     Neoplasms
#    hr
# 1  15.676656
# 2   8.865542
# 3   7.643901
# 4   6.949716
# 5   3.326236
# 6   2.842782
# 7   2.690668
# 8   2.668278
# 9   2.663540
# 10  2.567849
# 11  2.265232
# 12  2.256346
# 13  2.138969
# 14  2.090853
# 15  2.062731
# 16  2.021752
# 17  1.795993
# 18  1.686419
# 19  1.364880
# 20  1.259566

# %%
plot_width = 10; plot_height=5; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

temp_hr %>% 
    mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    mutate(phecode_category = factor(phecode_category, levels=pcats_sorted)) %>%
    filter(endpoint %in% endpoint_selection) %>%
    ggplot(aes(x=endpoint, y=hr, color=phecode_category)) + 
    geom_segment(aes(x=endpoint, xend=endpoint, y=0, yend=hr), color="black")+
    geom_point(size=1) + 
    geom_text(aes(y=hr+1, label=round(hr, 2)), size=2.5, hjust=-0)+
    geom_text(aes(y=hr+5, label=phecode_string), size=2.5, hjust=0)+
    coord_flip(ylim=c(0, 100)) + 
    facet_grid(rows=vars(phecode_category), scales="free_y", space="free_y")+
    theme(strip.text.y = element_text(angle=0))#+ facet_wrap(~phecode_category, scales="free_x")
# Out:
# plot without title

# %%
plot_width = 10; plot_height=75; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

temp_hr %>% 
    mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    mutate(phecode_category = factor(phecode_category, levels=pcats_sorted)) %>%
    filter(endpoint %in% endpoint_selection) %>%
    ggplot(aes(x=endpoint, y=hr, color=phecode_category)) + 
    geom_segment(aes(x=endpoint, xend=endpoint, y=0, yend=hr), color="black")+
    geom_point(size=1) + 
    geom_text(aes(y=hr+1, label=round(hr, 2)), size=2.5, hjust=-0)+
    geom_text(aes(y=hr+5, label=phecode_string), size=2.5, hjust=0)+
    coord_flip(ylim=c(0, 100)) + 
    facet_grid(rows=vars(phecode_category), scales="free_y", space="free_y")#+ facet_wrap(~phecode_category, scales="free_x")
# Out:
# plot without title

# %%
plot_width = 10; plot_height=10; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)
temp_hr %>% 
    mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    mutate(phecode_category = factor(phecode_category, levels=pcats_sorted)) %>%
    ggplot(aes(x=hr)) + geom_density(bw=1) + coord_cartesian(xlim=c(0, 20))
# Out:
# plot without title

# %%
endpoint_sample = (benchmark_endpoints %>% select(endpoint) %>% distinct() %>% sample_n(20))$endpoint

# %%
plot_width = 10; plot_height=5; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

scores_plot = c("AgeSex", "MedicalHistory", "Age+Sex+MedicalHistory")#, "AgeSexMedicalHistory")

temp = benchmark_endpoints %>% filter(score %in% scores_plot) %>% mutate(score = factor(score, levels=scores_plot)) %>% filter(endpoint %in% endpoint_sample)
temp %>% 
    ggplot(aes(x=score, y=cindex, fill=score, color=score)) + 
    geom_boxplot()+
    coord_flip()+
    #geom_violin(alpha=0.5) + 
    facet_wrap(~endpoint, labeller=labeller(endpoint=endpoint_map))
# Out:
# plot without title

# %%
# Out:
#     endpoint    score                  iteration time cindex    phecode
# 1   phecode_997 Age+Sex+MedicalHistory 0         10   0.7164782 997
# 2   phecode_997 AgeSex                 0         10   0.5988981 997
# 3   phecode_997 AgeSexMedicalHistory   0         10   0.7130266 997
# 4   phecode_997 MedicalHistory         0         10   0.7007227 997
# 5   phecode_997 Age+Sex+MedicalHistory 1         10   0.7103757 997
# 6   phecode_997 AgeSex                 1         10   0.5972712 997
# 7   phecode_997 AgeSexMedicalHistory   1         10   0.7058261 997
# 8   phecode_997 MedicalHistory         1         10   0.6928414 997
# 9   phecode_997 Age+Sex+MedicalHistory 2         10   0.7131720 997
# 10  phecode_997 AgeSex                 2         10   0.5987753 997
# 11  phecode_997 AgeSexMedicalHistory   2         10   0.7091720 997
# 12  phecode_997 MedicalHistory         2         10   0.6968872 997
# 13  phecode_997 Age+Sex+MedicalHistory 3         10   0.7117398 997
# 14  phecode_997 AgeSex                 3         10   0.5931846 997
# 15  phecode_997 AgeSexMedicalHistory   3         10   0.7093311 997
# 16  phecode_997 MedicalHistory         3         10   0.6976423 997
# 17  phecode_997 Age+Sex+MedicalHistory 4         10   0.7143707 997
# 18  phecode_997 AgeSex                 4         10   0.5961593 997
# 19  phecode_997 AgeSexMedicalHistory   4         10   0.7124745 997
# 20  phecode_997 MedicalHistory         4         10   0.7009488 997
# 21  phecode_997 Age+Sex+MedicalHistory 5         10   0.7128866 997
# 22  phecode_997 AgeSex                 5         10   0.6008851 997
# 23  phecode_997 AgeSexMedicalHistory   5         10   0.7078428 997
# 24  phecode_997 MedicalHistory         5         10   0.6963925 997
# 25  phecode_997 Age+Sex+MedicalHistory 6         10   0.7156238 997
# 26  phecode_997 AgeSex                 6         10   0.6003008 997
# 27  phecode_997 AgeSexMedicalHistory   6         10   0.7126175 997
# 28  phecode_997 MedicalHistory         6         10   0.7006525 997
# 29  phecode_997 Age+Sex+MedicalHistory 7         10   0.7067397 997
# 30  phecode_997 AgeSex                 7         10   0.5919076 997
# ⋮   ⋮           ⋮                      ⋮         ⋮    ⋮         ⋮
# 371 phecode_997 AgeSexMedicalHistory   92        10   0.7146041 997
# 372 phecode_997 MedicalHistory         92        10   0.7024323 997
# 373 phecode_997 Age+Sex+MedicalHistory 93        10   0.7169568 997
# 374 phecode_997 AgeSex                 93        10   0.5985403 997
# 375 phecode_997 AgeSexMedicalHistory   93        10   0.7133231 997
# 376 phecode_997 MedicalHistory         93        10   0.7019381 997
# 377 phecode_997 Age+Sex+MedicalHistory 94        10   0.7086847 997
# 378 phecode_997 AgeSex                 94        10   0.5939669 997
# 379 phecode_997 AgeSexMedicalHistory   94        10   0.7049945 997
# 380 phecode_997 MedicalHistory         94        10   0.6943191 997
# 381 phecode_997 Age+Sex+MedicalHistory 95        10   0.7155161 997
# 382 phecode_997 AgeSex                 95        10   0.6010089 997
# 383 phecode_997 AgeSexMedicalHistory   95        10   0.7111104 997
# 384 phecode_997 MedicalHistory         95        10   0.6999739 997
# 385 phecode_997 Age+Sex+MedicalHistory 96        10   0.7079958 997
# 386 phecode_997 AgeSex                 96        10   0.5900684 997
# 387 phecode_997 AgeSexMedicalHistory   96        10   0.7044606 997
# 388 phecode_997 MedicalHistory         96        10   0.6947631 997
# 389 phecode_997 Age+Sex+MedicalHistory 97        10   0.7121755 997
# 390 phecode_997 AgeSex                 97        10   0.5956554 997
# 391 phecode_997 AgeSexMedicalHistory   97        10   0.7091417 997
# 392 phecode_997 MedicalHistory         97        10   0.6972328 997
# 393 phecode_997 Age+Sex+MedicalHistory 98        10   0.7124103 997
# 394 phecode_997 AgeSex                 98        10   0.6030751 997
# 395 phecode_997 AgeSexMedicalHistory   98        10   0.7078865 997
# 13  997         1
# 14  997         1
# 15  997         1
# 16  997         1
# 17  997         1
# 18  997         1
# 19  997         1
# 20  997         1
# 21  997         1
# 22  997         1
# 23  997         1
# 24  997         1
# 25  997         1
# 26  997         1
# 27  997         1
# 28  997         1
# 29  997         1
# 30  997         1
# ⋮   ⋮           ⋮
# 371 997         1
# 372 997         1
# 373 997         1
# 374 997         1
# 375 997         1
# 376 997         1
# 377 997         1
# 378 997         1
# 379 997         1
# 380 997         1
# 381 997         1
# 382 997         1
# 383 997         1
# 384 997         1
# 385 997         1
# 386 997         1
# 387 997         1
# 388 997         1
# 389 997         1
# 390 997         1
# 391 997         1
# 392 997         1
# 393 997         1
# 394 997         1
# 395 997         1
# 396 997         1
# 397 997         1
# 398 997         1
# 399 997         1
# 400 997         1

# %% [markdown]
# ## Metabolic state and incident disease

# %%
pred_outcomes = predictions %>% left_join(data_outcomes, on=c(eid, endpoint)) %>% as.data.table()
# Out:
# Joining, by = c("eid", "endpoint")

# %%
logh_inc = pred_outcomes %>% filter(prevalent==0) %>% group_by(endpoint, model) %>% mutate(logh_perc = ntile(logh, 100)) %>% ungroup() %>% as_tibble()

# %% [markdown]
# ## No buffer

# %%
logh_T_agg = logh_inc %>% group_by(endpoint, model, logh_perc) %>% summarise(ratio = mean(event)) %>% as_tibble()
# Out:
# `summarise()` has grouped output by 'endpoint', 'model'. You can override using the `.groups` argument.

# %%
logh_T_agg %>% write_feather(glue("{output_path}/logh_agg_220224.feather"))

# %%
plot_width = 50; plot_height=75; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)
#temp_rank = event_rest %>% filter(features=="Metabolomics") %>% arrange(desc(MET10PercvsREST))
endpoint_order = (phecode_defs %>% mutate(phecode_rank = as.numeric(phecode)) %>% arrange(phecode_rank) %>% as_tibble())$endpoint
endpoint_selection = endpoint_order# %>% head(500)
temp = logh_T_agg %>% filter(model=="GNN(Records)+MLP") %>% mutate(endpoint = factor(endpoint, levels=endpoint_order)) %>% filter(endpoint %in% endpoint_selection) %>% ungroup() #%>% sample_n(10000)

mh_events = ggplot(temp, aes(x=logh_perc, y=ratio*100, color=logh_perc)) + 
    labs(title=NULL, x="Medical History Percentile [%]", y="Observed Event Rate [%]") +
    geom_point(alpha=0.7, size=0.1) + 
    scale_colour_gradient(
  low = "#7AC6FF",
  high = "#023768",
  space = "Lab",
  na.value = "grey50",
  guide = "colourbar",
  aesthetics = "colour"
)+
    #scale_color_manual(values=c("Metabolomics"="black"))+
    scale_y_continuous(limits=c(0, NA), expand=expansion(mult=c(0, .05)))+#, limits=c(0, NA))+
    scale_x_continuous(expand=expansion(add=c(0, 1)))+
    facet_wrap(~endpoint, scale="free", labeller = labeller(endpoint = endpoint_map), ncol=25) + theme(legend.position="none")

# %%
plot_name = "MedicalHistoryRisk"
mh_events %>% ggsave(filename=glue("outputs/{plot_name}.pdf"), device="pdf", width=plot_width, height=plot_height, dpi=plot_res, limitsize=FALSE)

# %%
plot_name = "MedicalHistoryRisk"
mh_events %>% ggsave(filename=glue("outputs/{plot_name}.png"), device="png", width=plot_width, height=plot_height, dpi=plot_res, limitsize=FALSE)

# %% [markdown]
# ## Add buffer

# %%
pred_outcomes %>% head()
# Out:
#   eid     partition model                 endpoint     logh      prevalent
# 1 1475839 0         Identity(Records)+MLP OMOP_4306655 -2.819316 0
# 2 1475840 0         Identity(Records)+MLP OMOP_4306655 -2.011223 0
# 3 1475853 0         Identity(Records)+MLP OMOP_4306655 -2.831062 0
# 4 1475862 0         Identity(Records)+MLP OMOP_4306655 -2.578309 0
# 5 1475871 0         Identity(Records)+MLP OMOP_4306655 -3.008898 0
# 6 1475886 0         Identity(Records)+MLP OMOP_4306655 -3.047699 0
#   event time
# 1 0     12.564256
# 2 1      6.817248
# 3 0     12.772336
# 4 0     11.660746
# 5 0     11.879779
# 6 0     12.646393

# %%
logh_T_agg_buffer = pred_outcomes %>% filter(prevalent==0) %>% mutate(event_buffer = case_when((event!=0&time<1) ~ 0, TRUE ~ event)) %>% group_by(endpoint, model) %>% mutate(logh_perc = ntile(logh, 100)) %>% group_by(endpoint, model, logh_perc) %>% summarise(ratio = mean(event_buffer)) %>% as_tibble()
# Out:
# `summarise()` has grouped output by 'endpoint', 'model'. You can override using the `.groups` argument.

# %%
logh_T_agg_buffer %>% write_feather(glue("{output_path}/logh_agg_1ybuffer_220224.feather"))

# %%
plot_width = 50; plot_height=75; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)
#temp_rank = event_rest %>% filter(features=="Metabolomics") %>% arrange(desc(MET10PercvsREST))
endpoint_order = (phecode_defs %>% mutate(phecode_rank = as.numeric(phecode)) %>% arrange(phecode_rank) %>% as_tibble())$endpoint
endpoint_selection = endpoint_order# %>% head(500)
temp = logh_T_agg_buffer %>% filter(model=="GNN(Records)+MLP") %>% mutate(endpoint = factor(endpoint, levels=endpoint_order)) %>% filter(endpoint %in% endpoint_selection) %>% ungroup() #%>% sample_n(10000)

mh_events = ggplot(temp, aes(x=logh_perc, y=ratio*100, color=logh_perc)) + 
    labs(title=NULL, x="Medical History Percentile [%]", y="Observed Event Rate [%]") +
    geom_point(alpha=0.7, size=0.1) + 
    scale_colour_gradient(
  low = "#7AC6FF",
  high = "#023768",
  space = "Lab",
  na.value = "grey50",
  guide = "colourbar",
  aesthetics = "colour"
)+
    #scale_color_manual(values=c("Metabolomics"="black"))+
    scale_y_continuous(limits=c(0, NA), expand=expansion(mult=c(0, .05)))+#, limits=c(0, NA))+
    scale_x_continuous(expand=expansion(add=c(0, 1)))+
    facet_wrap(~endpoint, scale="free", labeller = labeller(endpoint = endpoint_map), ncol=25) + theme(legend.position="none")

# %%
plot_name = "MedicalHistoryRisk_1ybuffer"
mh_events %>% ggsave(filename=glue("outputs/{plot_name}.png"), device="png", width=plot_width, height=plot_height, dpi=plot_res, limitsize=FALSE)

# %% [markdown]
# ## Metabolomic State and Event Trajectories

# %%
logh_mh = logh_inc %>% select(endpoint, model, eid, logh_perc, event, time) %>% group_by(endpoint) %>% 
    mutate(MH=case_when(logh_perc %in% 91:100 ~ "High", 
                        logh_perc %in% 45:55 ~ "Mid", 
                        logh_perc %in% 1:10 ~ "Low",
                        TRUE ~ "NA")
          ) %>% mutate(MET = fct_rev(factor(MET, levels=c("Low", "Mid", "High")))) %>% ungroup() %>% 
    filter(MH!="NA") #%>% select(eid, endpoint, logh, logh_group)

# %%
require("ggquickeda")
plot_width = 50; plot_height=75; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)
met_map = c("High"="#023768", "Mid"="#4F8EC1", "Low"="#7AC6FF")

endpoint_order = (phecode_defs %>% mutate(phecode_rank = as.numeric(phecode)) %>% arrange(phecode_rank) %>% as_tibble())$endpoint
endpoint_selection = endpoint_order# %>% head(500)
temp = logh_mh %>% mutate(endpoint = factor(endpoint, levels=endpoint_order)) %>% filter(endpoint %in% endpoint_selection) %>% ungroup() 

km_plot = ggplot(temp, aes(time = time, status = event, fill=MET, color=MET,group=MET)) +
    geom_km(trans = "event") + 
    geom_kmticks(trans = "event", size=0.3) + geom_kmband(trans = "event") + 
    labs(x="Time [Years]", y="Cumulative Events [%]")+
    scale_color_manual(values=met_map)+scale_fill_manual(values=met_map)+
    scale_y_continuous(labels = function(x) round(x*100, 1), expand=c(0, 0))+
    scale_x_continuous(expand=expansion(add=c(0, .1)), breaks=c(5, 10))+
    facet_wrap(~ endpoint, scale="free", labeller = labeller(endpoint = endpoint_map), ncol=25) + theme(legend.position="none")

# %%
plot_name = "MedicalHistory_KMs"
km_plot %>% ggsave(filename=glue("outputs/{plot_name}.png"), device="png", width=plot_width, height=plot_height, dpi=plot_res, limitsize=FALSE)

# %% [markdown]
# # Top 1%

# %%
logh_mh = logh_inc %>% select(endpoint, model, eid, logh_perc, event, time) %>% group_by(endpoint) %>% 
    mutate(MH=case_when(logh_perc == 100 ~ "High", 
                        logh_perc %in% 50:51 ~ "Mid", 
                        logh_perc == 1 ~ "Low",
                        TRUE ~ "NA")
          ) %>% mutate(MET = fct_rev(factor(MH, levels=c("Low", "Mid", "High")))) %>% ungroup() %>% 
    filter(MH!="NA") #%>% select(eid, endpoint, logh, logh_group)

# %%
require("ggquickeda")
plot_width = 50; plot_height=75; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)
mh_map = c("High"="#023768", "Mid"="#4F8EC1", "Low"="#7AC6FF")

endpoint_order = (phecode_defs %>% mutate(phecode_rank = as.numeric(phecode)) %>% arrange(phecode_rank) %>% as_tibble())$endpoint
endpoint_selection = endpoint_order# %>% head(500)
temp = logh_mh %>% mutate(endpoint = factor(endpoint, levels=endpoint_order)) %>% filter(endpoint %in% endpoint_selection) %>% ungroup() 

km_plot = ggplot(temp, aes(time = time, status = event, fill=MH, color=MH,group=MH)) +
    geom_km(trans = "event") + 
    geom_kmticks(trans = "event", size=0.3) + geom_kmband(trans = "event") + 
    labs(x="Time [Years]", y="Cumulative Events [%]")+
    scale_color_manual(values=met_map)+scale_fill_manual(values=mh_map)+
    scale_y_continuous(labels = function(x) round(x*100, 1), expand=c(0, 0))+
    scale_x_continuous(expand=expansion(add=c(0, .1)), breaks=c(5, 10))+
    facet_wrap(~ endpoint, scale="free", labeller = labeller(endpoint = endpoint_map), ncol=25) + theme(legend.position="none")

# %%
plot_name = "MedicalHistory_KMs_Top1"
km_plot %>% ggsave(filename=glue("outputs/{plot_name}.png"), device="png", width=plot_width, height=plot_height, dpi=plot_res, limitsize=FALSE)

# %% [markdown]
# # Figure 2

# %%
plot_width=8.25; plot_height=10; plot_dpi=320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_dpi)
fig2 = met_events / km_plot# +plot_annotation(tag_levels = 'A')

# %%
fig2

# %%
library(gt)
plot_name = "Figures_2_AB"
fig2 %>% ggsave(filename=glue("outputs/{plot_name}.pdf"), device="pdf", width=plot_width, height=plot_height, dpi=320)
